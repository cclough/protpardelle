# %%
# !pwd
# Out:
# /home/bournelab/qbi_hackathon

# %%
from pathlib import Path
import pandas as pd

# %%
clusters = Path("codnas_groups_pdb")

# %%
from biotite.structure.io.pdb import PDBFile
from biotite.structure import get_residue_starts
from biotite.sequence import ProteinSequence

# %%
def three_to_one(aa):
    try:
        return ProteinSequence.convert_letter_3to1(aa)
    except KeyError:
        return "X"

# %%
for cluster_dir in clusters.rglob("*"):
    cluster = cluster_dir.stem
    cluster_fasta = f"cluster_seqs/{cluster}_seqs.fasta"
    print(cluster_fasta)
    with open(f"cluster_seqs/{cluster}_seqs.fasta", "w") as f:
        for pdb_file in cluster_dir.glob("*.pdb"):
            if "fixed" in pdb_file.stem: continue
            parts = pdb_file.stem.split("-")
            pdb_f = PDBFile.read(str(pdb_file))
            pdb = pdb_f.get_structure(model=1)
            residues = "".join([three_to_one(aa) for aa in pdb.res_name[get_residue_starts(pdb)]])
            print(f">{parts[0]}_{parts[-1]} {parts[1] if len(pdb_file.stem) > 3 else ''}\n{residues}", file=f)
    print("done")
# Out:
# cluster_seqs/1EQT_A_seqs.fasta
# done
# cluster_seqs/2APO_B_seqs.fasta
# done
# cluster_seqs/3HWE_A_seqs.fasta
# done
# cluster_seqs/1ZOQ_C_seqs.fasta
# done
# cluster_seqs/2ELR_A_seqs.fasta
# done
# cluster_seqs/5B6Q_A_seqs.fasta
# done
# cluster_seqs/2MS8_A_seqs.fasta
# done
# cluster_seqs/2RUG_A_seqs.fasta
# done
# cluster_seqs/1X9V_A_seqs.fasta
# done
# cluster_seqs/4HI8_A_seqs.fasta
# done
# cluster_seqs/6OGK_A_seqs.fasta
# done
# cluster_seqs/2BJE_A_seqs.fasta
# done
# cluster_seqs/1X0F_A_seqs.fasta
# done
# cluster_seqs/2YT0_A_seqs.fasta
# done
# cluster_seqs/4YUD_A_seqs.fasta
# done
# cluster_seqs/6AC0_A_seqs.fasta
# done
# cluster_seqs/1OFF_A_seqs.fasta
# done
# cluster_seqs/2KP2_A_seqs.fasta
# done
# cluster_seqs/1HO9_A_seqs.fasta
# done
# cluster_seqs/1BHB_A_seqs.fasta
# done
# cluster_seqs/2L87_A_seqs.fasta
# done
# cluster_seqs/5URN_B_seqs.fasta
# done
# cluster_seqs/2RPQ_A_seqs.fasta
# done
# cluster_seqs/2L66_A_seqs.fasta
# done
# cluster_seqs/2Q44_A_seqs.fasta
# done
# cluster_seqs/1VPU_A_seqs.fasta
# done
# cluster_seqs/1F7M_A_seqs.fasta
# done
# cluster_seqs/6F4J_C_seqs.fasta
# done
# cluster_seqs/6SI7_A_seqs.fasta
# done
# cluster_seqs/5JTQ_A_seqs.fasta
# done
# cluster_seqs/6RK3_A_seqs.fasta
# done
# cluster_seqs/2MNU_A_seqs.fasta
# done
# cluster_seqs/1NJQ_A_seqs.fasta
# done
# cluster_seqs/3E9F_A_seqs.fasta
# done
# cluster_seqs/1T1V_A_seqs.fasta
# done
# cluster_seqs/2LNX_A_seqs.fasta
# done
# cluster_seqs/2LOW_A_seqs.fasta
# done
# cluster_seqs/1TNT_A_seqs.fasta
# done
# cluster_seqs/2K6G_A_seqs.fasta
# done
# cluster_seqs/1XYD_A_seqs.fasta
# done
# cluster_seqs/6YMX_e_seqs.fasta
# done
# cluster_seqs/2MLT_A_seqs.fasta
# done
# cluster_seqs/2K2T_A_seqs.fasta
# done
# cluster_seqs/3U88_C_seqs.fasta
# done
# cluster_seqs/3VVW_B_seqs.fasta
# done
# cluster_seqs/2LRR_A_seqs.fasta
# done
# cluster_seqs/1Y7J_A_seqs.fasta
# done
# cluster_seqs/2KQ6_A_seqs.fasta
# done
# cluster_seqs/2KCL_A_seqs.fasta
# done
# cluster_seqs/3Q15_C_seqs.fasta
# done
# cluster_seqs/2E2J_H_seqs.fasta
# done
# cluster_seqs/2K3U_A_seqs.fasta
# done
# cluster_seqs/5KJ3_A_seqs.fasta
# done
# cluster_seqs/2NA9_A_seqs.fasta
# done
# cluster_seqs/2LOZ_A_seqs.fasta
# done
# cluster_seqs/2I7U_A_seqs.fasta
# done
# cluster_seqs/2BNK_A_seqs.fasta
# done
# cluster_seqs/2LFS_A_seqs.fasta
# done
# cluster_seqs/4ZZ8_A_seqs.fasta
# done
# cluster_seqs/2QT4_A_seqs.fasta
# done
# cluster_seqs/3ZHF_A_seqs.fasta
# done
# cluster_seqs/2LZS_A_seqs.fasta
# done
# cluster_seqs/2MZF_A_seqs.fasta
# done
# cluster_seqs/1KN5_A_seqs.fasta
# done
# cluster_seqs/2LKC_A_seqs.fasta
# done
# cluster_seqs/1D8J_A_seqs.fasta
# done
# cluster_seqs/6B9W_A_seqs.fasta
# done
# cluster_seqs/3ALC_A_seqs.fasta
# done
# cluster_seqs/1FAC_A_seqs.fasta
# done
# cluster_seqs/6QKP_A_seqs.fasta
# done
# cluster_seqs/2P4L_A_seqs.fasta
# done
# cluster_seqs/1QIB_A_seqs.fasta
# done
# cluster_seqs/1DRS_A_seqs.fasta
# done
# cluster_seqs/2MMJ_A_seqs.fasta
# done
# cluster_seqs/2BBL_A_seqs.fasta
# done
# cluster_seqs/2KWK_B_seqs.fasta
# done
# cluster_seqs/2L4S_A_seqs.fasta
# done
# cluster_seqs/1GJS_A_seqs.fasta
# done
# cluster_seqs/1ZME_C_seqs.fasta
# done
# cluster_seqs/1WVH_A_seqs.fasta
# done
# cluster_seqs/7KLO_A_seqs.fasta
# done
# cluster_seqs/3NMR_A_seqs.fasta
# done
# cluster_seqs/2RQA_A_seqs.fasta
# done
# cluster_seqs/5JYN_A_seqs.fasta
# done
# cluster_seqs/6EJP_A_seqs.fasta
# done
# cluster_seqs/5L7M_A_seqs.fasta
# done
# cluster_seqs/4IFM_A_seqs.fasta
# done
# cluster_seqs/1N9J_A_seqs.fasta
# done
# cluster_seqs/6OSJ_A_seqs.fasta
# done
# cluster_seqs/1DX7_A_seqs.fasta
# done
# cluster_seqs/2MKC_B_seqs.fasta
# done
# cluster_seqs/1BLX_B_seqs.fasta
# done
# cluster_seqs/1POQ_A_seqs.fasta
# done
# cluster_seqs/2LAG_B_seqs.fasta
# done
# cluster_seqs/5WB2_B_seqs.fasta
# done
# cluster_seqs/3RUI_B_seqs.fasta
# done
# cluster_seqs/5L87_A_seqs.fasta
# done
# cluster_seqs/3F43_A_seqs.fasta
# done
# cluster_seqs/1J03_A_seqs.fasta
# done
# cluster_seqs/1EOT_A_seqs.fasta
# done
# cluster_seqs/4PJO_L_seqs.fasta
# done
# cluster_seqs/6OKW_A_seqs.fasta
# done
# cluster_seqs/3ZK6_A_seqs.fasta
# done
# cluster_seqs/1CKV_A_seqs.fasta
# done
# cluster_seqs/6NY8_A_seqs.fasta
# done
# cluster_seqs/4ZKB_B_seqs.fasta
# done
# cluster_seqs/2KTF_B_seqs.fasta
# done
# cluster_seqs/6D3T_A_seqs.fasta
# done
# cluster_seqs/3CWI_A_seqs.fasta
# done
# cluster_seqs/2M8M_A_seqs.fasta
# done
# cluster_seqs/1KBA_A_seqs.fasta
# done
# cluster_seqs/2RNB_A_seqs.fasta
# done
# cluster_seqs/2KED_A_seqs.fasta
# done
# cluster_seqs/4JNE_A_seqs.fasta
# done
# cluster_seqs/6D53_C_seqs.fasta
# done
# cluster_seqs/2BYF_A_seqs.fasta
# done
# cluster_seqs/6AKP_C_seqs.fasta
# done
# cluster_seqs/2F3W_A_seqs.fasta
# done
# cluster_seqs/1Z00_A_seqs.fasta
# done
# cluster_seqs/2IWJ_A_seqs.fasta
# done
# cluster_seqs/4CGU_A_seqs.fasta
# done
# cluster_seqs/1O1W_A_seqs.fasta
# done
# cluster_seqs/6MYH_B_seqs.fasta
# done
# cluster_seqs/1U34_A_seqs.fasta
# done
# cluster_seqs/2MDK_A_seqs.fasta
# done
# cluster_seqs/7L54_A_seqs.fasta
# done
# cluster_seqs/2RS7_A_seqs.fasta
# done
# cluster_seqs/2LJI_A_seqs.fasta
# done
# cluster_seqs/1WHQ_A_seqs.fasta
# done
# cluster_seqs/2B7T_A_seqs.fasta
# done
# cluster_seqs/2KB7_P_seqs.fasta
# done
# cluster_seqs/1NRE_A_seqs.fasta
# done
# cluster_seqs/1THQ_A_seqs.fasta
# done
# cluster_seqs/2WQI_A_seqs.fasta
# done
# cluster_seqs/2F5H_A_seqs.fasta
# done
# cluster_seqs/1DTC_A_seqs.fasta
# done
# cluster_seqs/1WHF_A_seqs.fasta
# done
# cluster_seqs/5TGW_A_seqs.fasta
# done
# cluster_seqs/4LJX_A_seqs.fasta
# done
# cluster_seqs/2DDY_A_seqs.fasta
# done
# cluster_seqs/5H7P_B_seqs.fasta
# done
# cluster_seqs/2MJ8_A_seqs.fasta
# done
# cluster_seqs/1ZDC_A_seqs.fasta
# done
# cluster_seqs/3GN5_B_seqs.fasta
# done
# cluster_seqs/2RNM_A_seqs.fasta
# done
# cluster_seqs/2JPK_A_seqs.fasta
# done
# cluster_seqs/2ES9_A_seqs.fasta
# done
# cluster_seqs/1BLK_A_seqs.fasta
# done
# cluster_seqs/2KE1_A_seqs.fasta
# done
# cluster_seqs/2CLY_C_seqs.fasta
# done
# cluster_seqs/5UA8_A_seqs.fasta
# done
# cluster_seqs/2K9B_A_seqs.fasta
# done
# cluster_seqs/1JIZ_A_seqs.fasta
# done
# cluster_seqs/2M0D_A_seqs.fasta
# done
# cluster_seqs/6NHW_A_seqs.fasta
# done
# cluster_seqs/2KRE_A_seqs.fasta
# done
# cluster_seqs/2N8U_A_seqs.fasta
# done
# cluster_seqs/1HCF_X_seqs.fasta
# done
# cluster_seqs/1A5R_A_seqs.fasta
# done
# cluster_seqs/1XCT_P_seqs.fasta
# done
# cluster_seqs/4ICK_A_seqs.fasta
# done
# cluster_seqs/1TVT_A_seqs.fasta
# done
# cluster_seqs/6FEG_A_seqs.fasta
# done
# cluster_seqs/2XNF_A_seqs.fasta
# done
# cluster_seqs/5IA7_A_seqs.fasta
# done
# cluster_seqs/2HI7_A_seqs.fasta
# done
# cluster_seqs/2JWD_A_seqs.fasta
# done
# cluster_seqs/1RU2_A_seqs.fasta
# done
# cluster_seqs/3AAF_A_seqs.fasta
# done
# cluster_seqs/1N3G_A_seqs.fasta
# done
# cluster_seqs/2K6M_S_seqs.fasta
# done
# cluster_seqs/6P9Y_P_seqs.fasta
# done
# cluster_seqs/4DT6_A_seqs.fasta
# done
# cluster_seqs/6FZK_A_seqs.fasta
# done
# cluster_seqs/1I3O_E_seqs.fasta
# done
# cluster_seqs/1WA8_A_seqs.fasta
# done
# cluster_seqs/6DMX_D_seqs.fasta
# done
# cluster_seqs/6Z0I_A_seqs.fasta
# done
# cluster_seqs/2K5U_A_seqs.fasta
# done
# cluster_seqs/2DOI_C_seqs.fasta
# done
# cluster_seqs/6D12_A_seqs.fasta
# done
# cluster_seqs/6Y3H_A_seqs.fasta
# done
# cluster_seqs/2KJC_A_seqs.fasta
# done
# cluster_seqs/5XI9_A_seqs.fasta
# done
# cluster_seqs/5YOK_A_seqs.fasta
# done
# cluster_seqs/1B0N_B_seqs.fasta
# done
# cluster_seqs/1A66_A_seqs.fasta
# done
# cluster_seqs/3LEU_A_seqs.fasta
# done
# cluster_seqs/2KDM_A_seqs.fasta
# done
# cluster_seqs/2MVH_A_seqs.fasta
# done
# cluster_seqs/1BF9_A_seqs.fasta
# done
# cluster_seqs/1D2Z_A_seqs.fasta
# done
# cluster_seqs/1XU1_R_seqs.fasta
# done
# cluster_seqs/1E9J_A_seqs.fasta
# done
# cluster_seqs/4FZ5_A_seqs.fasta
# done
# cluster_seqs/1DF4_A_seqs.fasta
# done
# cluster_seqs/2K1L_A_seqs.fasta
# done
# cluster_seqs/1WNN_A_seqs.fasta
# done
# cluster_seqs/1Z7R_A_seqs.fasta
# done
# cluster_seqs/1SX1_A_seqs.fasta
# done
# cluster_seqs/1X3B_A_seqs.fasta
# done
# cluster_seqs/1BI6_H_seqs.fasta
# done
# cluster_seqs/2AZV_A_seqs.fasta
# done
# cluster_seqs/3GM2_A_seqs.fasta
# done
# cluster_seqs/1L8C_B_seqs.fasta
# done
# cluster_seqs/3UYO_A_seqs.fasta
# done
# cluster_seqs/4ZKA_A_seqs.fasta
# done
# cluster_seqs/4FYH_A_seqs.fasta
# done
# cluster_seqs/2MLU_A_seqs.fasta
# done
# cluster_seqs/1HSN_A_seqs.fasta
# done
# cluster_seqs/2KPF_A_seqs.fasta
# done
# cluster_seqs/5J6Z_B_seqs.fasta
# done
# cluster_seqs/2LR6_A_seqs.fasta
# done
# cluster_seqs/6F0Y_A_seqs.fasta
# done
# cluster_seqs/2JND_B_seqs.fasta
# done
# cluster_seqs/2DJY_B_seqs.fasta
# done
# cluster_seqs/2MT5_A_seqs.fasta
# done
# cluster_seqs/2KA4_A_seqs.fasta
# done
# cluster_seqs/5E4A_A_seqs.fasta
# done
# cluster_seqs/1PV3_A_seqs.fasta
# done
# cluster_seqs/1A64_A_seqs.fasta
# done
# cluster_seqs/1IDY_A_seqs.fasta
# done
# cluster_seqs/2DKW_A_seqs.fasta
# done
# cluster_seqs/3CR4_X_seqs.fasta
# done
# cluster_seqs/2K6T_B_seqs.fasta
# done
# cluster_seqs/6MZA_A_seqs.fasta
# done
# cluster_seqs/1MO1_B_seqs.fasta
# done
# cluster_seqs/2YZ8_A_seqs.fasta
# done
# cluster_seqs/1IO4_C_seqs.fasta
# done
# cluster_seqs/2LPY_A_seqs.fasta
# done
# cluster_seqs/1YR1_A_seqs.fasta
# done
# cluster_seqs/4XJE_A_seqs.fasta
# done
# cluster_seqs/3PYJ_A_seqs.fasta
# done
# cluster_seqs/2LB6_A_seqs.fasta
# done
# cluster_seqs/5AER_A_seqs.fasta
# done
# cluster_seqs/1H1J_S_seqs.fasta
# done
# cluster_seqs/2PP4_A_seqs.fasta
# done
# cluster_seqs/6THL_B_seqs.fasta
# done
# cluster_seqs/2NCO_A_seqs.fasta
# done
# cluster_seqs/5CW7_A_seqs.fasta
# done
# cluster_seqs/2L5D_A_seqs.fasta
# done
# cluster_seqs/2KYI_A_seqs.fasta
# done
# cluster_seqs/1L5C_A_seqs.fasta
# done
# cluster_seqs/2JUW_A_seqs.fasta
# done
# cluster_seqs/2KO0_A_seqs.fasta
# done
# cluster_seqs/3FHU_A_seqs.fasta
# done
# cluster_seqs/2KE3_A_seqs.fasta
# done
# cluster_seqs/2RQ9_A_seqs.fasta
# done
# cluster_seqs/2M28_A_seqs.fasta
# done
# cluster_seqs/1T3X_A_seqs.fasta
# done
# cluster_seqs/2ELU_A_seqs.fasta
# done
# cluster_seqs/4Y9H_A_seqs.fasta
# done
# cluster_seqs/2LJE_A_seqs.fasta
# done
# cluster_seqs/2JR2_A_seqs.fasta
# done
# cluster_seqs/2L4Q_A_seqs.fasta
# done
# cluster_seqs/1ZWV_A_seqs.fasta
# done
# cluster_seqs/6W92_A_seqs.fasta
# done
# cluster_seqs/5LG7_A_seqs.fasta
# done
# cluster_seqs/2CX7_A_seqs.fasta
# done
# cluster_seqs/2OJ2_A_seqs.fasta
# done
# cluster_seqs/2YTN_A_seqs.fasta
# done
# cluster_seqs/1GHT_A_seqs.fasta
# done
# cluster_seqs/2BP3_A_seqs.fasta
# done
# cluster_seqs/3UX2_A_seqs.fasta
# done
# cluster_seqs/2RND_A_seqs.fasta
# done
# cluster_seqs/6TJ3_A_seqs.fasta
# done
# cluster_seqs/4B2B_B_seqs.fasta
# done
# cluster_seqs/2JYI_A_seqs.fasta
# done
# cluster_seqs/6IMQ_A_seqs.fasta
# done
# cluster_seqs/1K2H_A_seqs.fasta
# done
# cluster_seqs/2N70_A_seqs.fasta
# done
# cluster_seqs/451C_A_seqs.fasta
# done
# cluster_seqs/1YTV_A_seqs.fasta
# done
# cluster_seqs/6SDW_A_seqs.fasta
# done
# cluster_seqs/2M2P_B_seqs.fasta
# done
# cluster_seqs/1CTA_A_seqs.fasta
# done
# cluster_seqs/2B8A_A_seqs.fasta
# done
# cluster_seqs/1P8Z_G_seqs.fasta
# done
# cluster_seqs/1LV9_A_seqs.fasta
# done
# cluster_seqs/2DID_A_seqs.fasta
# done
# cluster_seqs/4MJH_A_seqs.fasta
# done
# cluster_seqs/2FD6_A_seqs.fasta
# done
# cluster_seqs/2I94_A_seqs.fasta
# done
# cluster_seqs/1ZTN_A_seqs.fasta
# done
# cluster_seqs/7DN3_F_seqs.fasta
# done
# cluster_seqs/3L1G_A_seqs.fasta
# done
# cluster_seqs/2RQC_A_seqs.fasta
# done
# cluster_seqs/1KLR_A_seqs.fasta
# done
# cluster_seqs/1MB1_A_seqs.fasta
# done
# cluster_seqs/2M7Q_A_seqs.fasta
# done
# cluster_seqs/2CZU_A_seqs.fasta
# done
# cluster_seqs/2L37_A_seqs.fasta
# done
# cluster_seqs/2FYJ_A_seqs.fasta
# done
# cluster_seqs/1J5N_A_seqs.fasta
# done
# cluster_seqs/2VDB_B_seqs.fasta
# done
# cluster_seqs/3CLN_A_seqs.fasta
# done
# cluster_seqs/2IV6_A_seqs.fasta
# done
# cluster_seqs/6HTF_A_seqs.fasta
# done
# cluster_seqs/6SQO_A_seqs.fasta
# done
# cluster_seqs/2MVM_A_seqs.fasta
# done
# cluster_seqs/1AK7_A_seqs.fasta
# done
# cluster_seqs/2M94_A_seqs.fasta
# done
# cluster_seqs/2MAE_A_seqs.fasta
# done
# cluster_seqs/2LQH_B_seqs.fasta
# done
# cluster_seqs/6EZN_D_seqs.fasta
# done
# cluster_seqs/4J3O_C_seqs.fasta
# done
# cluster_seqs/6UZ4_A_seqs.fasta
# done
# cluster_seqs/4J23_A_seqs.fasta
# done
# cluster_seqs/2MOG_A_seqs.fasta
# done
# cluster_seqs/2HTS_A_seqs.fasta
# done
# cluster_seqs/5E0Z_A_seqs.fasta
# done
# cluster_seqs/2N8L_A_seqs.fasta
# done
# cluster_seqs/4FA0_A_seqs.fasta
# done
# cluster_seqs/6N60_M_seqs.fasta
# done
# cluster_seqs/5J4Q_B_seqs.fasta
# done
# cluster_seqs/1BEH_A_seqs.fasta
# done
# cluster_seqs/2KTV_A_seqs.fasta
# done
# cluster_seqs/6POJ_A_seqs.fasta
# done
# cluster_seqs/1E7J_A_seqs.fasta
# done
# cluster_seqs/1N1U_A_seqs.fasta
# done
# cluster_seqs/5L7B_A_seqs.fasta
# done
# cluster_seqs/2ROK_A_seqs.fasta
# done
# cluster_seqs/2N2W_B_seqs.fasta
# done
# cluster_seqs/1CM9_A_seqs.fasta
# done
# cluster_seqs/4JPB_W_seqs.fasta
# done
# cluster_seqs/1KJK_A_seqs.fasta
# done
# cluster_seqs/6NXL_A_seqs.fasta
# done
# cluster_seqs/6U3R_A_seqs.fasta
# done
# cluster_seqs/2MJO_A_seqs.fasta
# done
# cluster_seqs/3FT7_A_seqs.fasta
# done
# cluster_seqs/1QCE_A_seqs.fasta
# done
# cluster_seqs/3QHT_A_seqs.fasta
# done
# cluster_seqs/4ADO_A_seqs.fasta
# done
# cluster_seqs/1DU2_A_seqs.fasta
# done
# cluster_seqs/1SKT_A_seqs.fasta
# done
# cluster_seqs/2CRH_A_seqs.fasta
# done
# cluster_seqs/2DAQ_A_seqs.fasta
# done
# cluster_seqs/2MUR_A_seqs.fasta
# done
# cluster_seqs/2ELV_A_seqs.fasta
# done
# cluster_seqs/2JHB_A_seqs.fasta
# done
# cluster_seqs/2KDS_A_seqs.fasta
# done
# cluster_seqs/1Z9E_A_seqs.fasta
# done
# cluster_seqs/1JSP_A_seqs.fasta
# done
# cluster_seqs/4I6P_A_seqs.fasta
# done
# cluster_seqs/1FAR_A_seqs.fasta
# done
# cluster_seqs/2XIU_A_seqs.fasta
# done
# cluster_seqs/1E41_A_seqs.fasta
# done
# cluster_seqs/1YX5_A_seqs.fasta
# done
# cluster_seqs/2EXF_A_seqs.fasta
# done
# cluster_seqs/2KHP_A_seqs.fasta
# done
# cluster_seqs/4AXP_A_seqs.fasta
# done
# cluster_seqs/3RCP_A_seqs.fasta
# done
# cluster_seqs/4LG7_A_seqs.fasta
# done
# cluster_seqs/2MHQ_A_seqs.fasta
# done
# cluster_seqs/3EGF_A_seqs.fasta
# done
# cluster_seqs/2MV9_A_seqs.fasta
# done
# cluster_seqs/2OS6_A_seqs.fasta
# done
# cluster_seqs/1QAV_B_seqs.fasta
# done
# cluster_seqs/3AV1_A_seqs.fasta
# done
# cluster_seqs/1V3A_A_seqs.fasta
# done
# cluster_seqs/1R69_A_seqs.fasta
# done
# cluster_seqs/1Z3K_A_seqs.fasta
# done
# cluster_seqs/1KL8_B_seqs.fasta
# done
# cluster_seqs/2RNR_A_seqs.fasta
# done
# cluster_seqs/2YTH_A_seqs.fasta
# done
# cluster_seqs/2KGC_A_seqs.fasta
# done
# cluster_seqs/6I8X_A_seqs.fasta
# done
# cluster_seqs/1MVI_A_seqs.fasta
# done
# cluster_seqs/2HVA_A_seqs.fasta
# done
# cluster_seqs/3GA3_A_seqs.fasta
# done
# cluster_seqs/1FVN_A_seqs.fasta
# done
# cluster_seqs/2V83_A_seqs.fasta
# done
# cluster_seqs/6YHF_A_seqs.fasta
# done
# cluster_seqs/2AJO_A_seqs.fasta
# done
# cluster_seqs/3NTW_B_seqs.fasta
# done
# cluster_seqs/6KHI_1_seqs.fasta
# done
# cluster_seqs/2KCP_A_seqs.fasta
# done
# cluster_seqs/6U4M_A_seqs.fasta
# done
# cluster_seqs/2RS8_A_seqs.fasta
# done
# cluster_seqs/2LCA_A_seqs.fasta
# done
# cluster_seqs/2KZG_A_seqs.fasta
# done
# cluster_seqs/1AX3_A_seqs.fasta
# done
# cluster_seqs/6KZ7_B_seqs.fasta
# done
# cluster_seqs/6AE8_A_seqs.fasta
# done
# cluster_seqs/1BBA_A_seqs.fasta
# done
# cluster_seqs/2RUK_B_seqs.fasta
# done
# cluster_seqs/6O7D_A_seqs.fasta
# done
# cluster_seqs/2KSM_A_seqs.fasta
# done
# cluster_seqs/1T0V_A_seqs.fasta
# done
# cluster_seqs/2MBE_A_seqs.fasta
# done
# cluster_seqs/6EVI_A_seqs.fasta
# done
# cluster_seqs/5GLH_B_seqs.fasta
# done
# cluster_seqs/5L2L_A_seqs.fasta
# done
# cluster_seqs/4C2B_B_seqs.fasta
# done
# cluster_seqs/2NB4_A_seqs.fasta
# done
# cluster_seqs/1P22_C_seqs.fasta
# done
# cluster_seqs/2KXC_B_seqs.fasta
# done
# cluster_seqs/2LKJ_A_seqs.fasta
# done
# cluster_seqs/2MRJ_A_seqs.fasta
# done
# cluster_seqs/4L1P_B_seqs.fasta
# done
# cluster_seqs/1MK3_A_seqs.fasta
# done
# cluster_seqs/1HNS_A_seqs.fasta
# done
# cluster_seqs/3OER_A_seqs.fasta
# done
# cluster_seqs/3CW2_K_seqs.fasta
# done
# cluster_seqs/2G46_C_seqs.fasta
# done
# cluster_seqs/2L4K_A_seqs.fasta
# done
# cluster_seqs/2MC4_A_seqs.fasta
# done
# cluster_seqs/2CIU_A_seqs.fasta
# done
# cluster_seqs/2LOO_A_seqs.fasta
# done
# cluster_seqs/1N8S_C_seqs.fasta
# done
# cluster_seqs/2W1O_A_seqs.fasta
# done
# cluster_seqs/3K65_B_seqs.fasta
# done
# cluster_seqs/2MAO_A_seqs.fasta
# done
# cluster_seqs/1RD4_A_seqs.fasta
# done
# cluster_seqs/6G4X_A_seqs.fasta
# done
# cluster_seqs/6PHO_A_seqs.fasta
# done
# cluster_seqs/6RF8_N_seqs.fasta
# done
# cluster_seqs/2MAK_A_seqs.fasta
# done
# cluster_seqs/1GT0_D_seqs.fasta
# done
# cluster_seqs/6CGW_A_seqs.fasta
# done
# cluster_seqs/3QJK_A_seqs.fasta
# done
# cluster_seqs/4N4C_A_seqs.fasta
# done
# cluster_seqs/1DD2_A_seqs.fasta
# done
# cluster_seqs/1U6P_A_seqs.fasta
# done
# cluster_seqs/5L8I_A_seqs.fasta
# done
# cluster_seqs/2JDQ_D_seqs.fasta
# done
# cluster_seqs/1N3K_A_seqs.fasta
# done
# cluster_seqs/2K7X_A_seqs.fasta
# done
# cluster_seqs/2L1P_A_seqs.fasta
# done
# cluster_seqs/1V5I_B_seqs.fasta
# done
# cluster_seqs/4A1G_A_seqs.fasta
# done
# cluster_seqs/1RJ2_A_seqs.fasta
# done
# cluster_seqs/2LOX_A_seqs.fasta
# done
# cluster_seqs/2PST_X_seqs.fasta
# done
# cluster_seqs/1OHN_A_seqs.fasta
# done
# cluster_seqs/6AMR_A_seqs.fasta
# done
# cluster_seqs/4MXW_V_seqs.fasta
# done
# cluster_seqs/2LRN_A_seqs.fasta
# done
# cluster_seqs/4QU6_A_seqs.fasta
# done
# cluster_seqs/1RGW_A_seqs.fasta
# done
# cluster_seqs/1T92_A_seqs.fasta
# done
# cluster_seqs/2RQM_A_seqs.fasta
# done
# cluster_seqs/1E1W_A_seqs.fasta
# done
# cluster_seqs/1MNL_A_seqs.fasta
# done
# cluster_seqs/2VGH_A_seqs.fasta
# done
# cluster_seqs/2N4Q_B_seqs.fasta
# done
# cluster_seqs/6O8P_X_seqs.fasta
# done
# cluster_seqs/2KA7_A_seqs.fasta
# done
# cluster_seqs/2FWU_A_seqs.fasta
# done
# cluster_seqs/3GGL_A_seqs.fasta
# done
# cluster_seqs/2FWS_A_seqs.fasta
# done
# cluster_seqs/4C0O_C_seqs.fasta
# done
# cluster_seqs/1WAA_F_seqs.fasta
# done
# cluster_seqs/5CRO_O_seqs.fasta
# done
# cluster_seqs/4R71_E_seqs.fasta
# done
# cluster_seqs/1URF_A_seqs.fasta
# done
# cluster_seqs/2YGN_A_seqs.fasta
# done
# cluster_seqs/6CZW_B_seqs.fasta
# done
# cluster_seqs/2IJK_A_seqs.fasta
# done
# cluster_seqs/1X3P_A_seqs.fasta
# done
# cluster_seqs/2KYV_A_seqs.fasta
# done
# cluster_seqs/2CG6_A_seqs.fasta
# done
# cluster_seqs/6G81_A_seqs.fasta
# done
# cluster_seqs/2MLE_C_seqs.fasta
# done
# cluster_seqs/1IKL_A_seqs.fasta
# done
# cluster_seqs/3ZE3_A_seqs.fasta
# done
# cluster_seqs/3IMD_A_seqs.fasta
# done
# cluster_seqs/6O0I_A_seqs.fasta
# done
# cluster_seqs/2K1W_A_seqs.fasta
# done
# cluster_seqs/2M6B_A_seqs.fasta
# done
# cluster_seqs/1PWT_A_seqs.fasta
# done
# cluster_seqs/2KQW_A_seqs.fasta
# done
# cluster_seqs/2N3T_A_seqs.fasta
# done
# cluster_seqs/6LRY_B_seqs.fasta
# done
# cluster_seqs/1DAV_A_seqs.fasta
# done
# cluster_seqs/1XHH_A_seqs.fasta
# done
# cluster_seqs/2LZG_A_seqs.fasta
# done
# cluster_seqs/1GCF_A_seqs.fasta
# done
# cluster_seqs/4F44_A_seqs.fasta
# done
# cluster_seqs/5X3Z_A_seqs.fasta
# done
# cluster_seqs/2KC1_A_seqs.fasta
# done
# cluster_seqs/3N9B_A_seqs.fasta
# done
# cluster_seqs/2K17_A_seqs.fasta
# done
# cluster_seqs/2L8T_A_seqs.fasta
# done
# cluster_seqs/2YXM_A_seqs.fasta
# done
# cluster_seqs/2EZI_A_seqs.fasta
# done
# cluster_seqs/5KWQ_A_seqs.fasta
# done
# cluster_seqs/2RPJ_A_seqs.fasta
# done
# cluster_seqs/6LXN_A_seqs.fasta
# done
# cluster_seqs/2E61_A_seqs.fasta
# done
# cluster_seqs/2LLS_A_seqs.fasta
# done
# cluster_seqs/2LRE_A_seqs.fasta
# done
# cluster_seqs/1HI7_A_seqs.fasta
# done
# cluster_seqs/1L4W_A_seqs.fasta
# done
# cluster_seqs/2M7S_A_seqs.fasta
# done
# cluster_seqs/1SJT_B_seqs.fasta
# done
# cluster_seqs/2LAE_A_seqs.fasta
# done
# cluster_seqs/2KOD_A_seqs.fasta
# done
# cluster_seqs/1CSZ_A_seqs.fasta
# done
# cluster_seqs/2N1W_A_seqs.fasta
# done
# cluster_seqs/5FE7_A_seqs.fasta
# done
# cluster_seqs/6GSF_A_seqs.fasta
# done
# cluster_seqs/2JPU_A_seqs.fasta
# done
# cluster_seqs/3FN1_B_seqs.fasta
# done
# cluster_seqs/2FHW_B_seqs.fasta
# done
# cluster_seqs/2KO7_A_seqs.fasta
# done
# cluster_seqs/1T84_A_seqs.fasta
# done
# cluster_seqs/2K4E_A_seqs.fasta
# done
# cluster_seqs/1OJ5_A_seqs.fasta
# done
# cluster_seqs/2JSH_A_seqs.fasta
# done
# cluster_seqs/4QT3_A_seqs.fasta
# done
# cluster_seqs/2H9Z_A_seqs.fasta
# done
# cluster_seqs/2REX_A_seqs.fasta
# done
# cluster_seqs/2QZT_A_seqs.fasta
# done
# cluster_seqs/5KQC_A_seqs.fasta
# done
# cluster_seqs/2JQF_R_seqs.fasta
# done
# cluster_seqs/5II7_A_seqs.fasta
# done
# cluster_seqs/2M5P_X_seqs.fasta
# done
# cluster_seqs/2MG2_A_seqs.fasta
# done
# cluster_seqs/3KYW_A_seqs.fasta
# done
# cluster_seqs/2KUP_A_seqs.fasta
# done
# cluster_seqs/6RLX_B_seqs.fasta
# done
# cluster_seqs/1KJ0_A_seqs.fasta
# done
# cluster_seqs/2LJ2_A_seqs.fasta
# done
# cluster_seqs/1YWS_A_seqs.fasta
# done
# cluster_seqs/1ZFL_A_seqs.fasta
# done
# cluster_seqs/1SOS_A_seqs.fasta
# done
# cluster_seqs/6TRI_B_seqs.fasta
# done
# cluster_seqs/2LS9_A_seqs.fasta
# done
# cluster_seqs/4NIK_A_seqs.fasta
# done
# cluster_seqs/7JGI_A_seqs.fasta
# done
# cluster_seqs/2A20_A_seqs.fasta
# done
# cluster_seqs/2KPL_A_seqs.fasta
# done
# cluster_seqs/5UJH_A_seqs.fasta
# done
# cluster_seqs/4FZ1_D_seqs.fasta
# done
# cluster_seqs/2BTT_A_seqs.fasta
# done
# cluster_seqs/2BO5_A_seqs.fasta
# done
# cluster_seqs/5FA5_C_seqs.fasta
# done
# cluster_seqs/2A5E_A_seqs.fasta
# done
# cluster_seqs/1BFX_A_seqs.fasta
# done
# cluster_seqs/6WNR_H_seqs.fasta
# done
# cluster_seqs/3K75_B_seqs.fasta
# done
# cluster_seqs/2KM4_A_seqs.fasta
# done
# cluster_seqs/2RMR_A_seqs.fasta
# done
# cluster_seqs/1IJZ_A_seqs.fasta
# done
# cluster_seqs/3IM5_A_seqs.fasta
# done
# cluster_seqs/2N75_A_seqs.fasta
# done
# cluster_seqs/6U4A_A_seqs.fasta
# done
# cluster_seqs/1TMQ_B_seqs.fasta
# done
# cluster_seqs/2MKE_A_seqs.fasta
# done
# cluster_seqs/1WLP_B_seqs.fasta
# done
# cluster_seqs/6SJW_A_seqs.fasta
# done
# cluster_seqs/2RSI_A_seqs.fasta
# done
# cluster_seqs/2KUN_A_seqs.fasta
# done
# cluster_seqs/4AWX_B_seqs.fasta
# done
# cluster_seqs/1RG0_A_seqs.fasta
# done
# cluster_seqs/6GBE_A_seqs.fasta
# done
# cluster_seqs/2RM0_W_seqs.fasta
# done
# cluster_seqs/2KTE_A_seqs.fasta
# done
# cluster_seqs/1TAP_A_seqs.fasta
# done
# cluster_seqs/4XK8_J_seqs.fasta
# done
# cluster_seqs/5TR5_A_seqs.fasta
# done
# cluster_seqs/3S9G_A_seqs.fasta
# done
# cluster_seqs/3NX0_A_seqs.fasta
# done
# cluster_seqs/2M4F_A_seqs.fasta
# done
# cluster_seqs/2L4U_A_seqs.fasta
# done
# cluster_seqs/2KBX_B_seqs.fasta
# done
# cluster_seqs/2MRN_A_seqs.fasta
# done
# cluster_seqs/6IZE_A_seqs.fasta
# done
# cluster_seqs/2DAY_A_seqs.fasta
# done
# cluster_seqs/3GAT_A_seqs.fasta
# done
# cluster_seqs/2JOK_A_seqs.fasta
# done
# cluster_seqs/6UZ4_B_seqs.fasta
# done
# cluster_seqs/1T23_A_seqs.fasta
# done
# cluster_seqs/5KS6_A_seqs.fasta
# done
# cluster_seqs/2RMZ_A_seqs.fasta
# done
# cluster_seqs/2RVL_A_seqs.fasta
# done
# cluster_seqs/1DU0_A_seqs.fasta
# done
# cluster_seqs/2L51_A_seqs.fasta
# done
# cluster_seqs/2EZE_A_seqs.fasta
# done
# cluster_seqs/1ZLH_B_seqs.fasta
# done
# cluster_seqs/1BJX_A_seqs.fasta
# done
# cluster_seqs/2RU5_B_seqs.fasta
# done
# cluster_seqs/1G1E_B_seqs.fasta
# done
# cluster_seqs/3ZR8_X_seqs.fasta
# done
# cluster_seqs/6NY6_S_seqs.fasta
# done
# cluster_seqs/2CJK_A_seqs.fasta
# done
# cluster_seqs/2KHN_A_seqs.fasta
# done
# cluster_seqs/1Z2D_A_seqs.fasta
# done
# cluster_seqs/3I5J_E_seqs.fasta
# done
# cluster_seqs/2EWL_A_seqs.fasta
# done
# cluster_seqs/1S69_A_seqs.fasta
# done
# cluster_seqs/1CJ5_A_seqs.fasta
# done
# cluster_seqs/1PQX_A_seqs.fasta
# done
# cluster_seqs/1BKU_A_seqs.fasta
# done
# cluster_seqs/2KDZ_A_seqs.fasta
# done
# cluster_seqs/1ORC_A_seqs.fasta
# done
# cluster_seqs/1LS8_A_seqs.fasta
# done
# cluster_seqs/2KW8_A_seqs.fasta
# done
# cluster_seqs/2KZS_A_seqs.fasta
# done
# cluster_seqs/2JMJ_A_seqs.fasta
# done
# cluster_seqs/2RSH_A_seqs.fasta
# done
# cluster_seqs/1X9L_A_seqs.fasta
# done
# cluster_seqs/5OHD_A_seqs.fasta
# done
# cluster_seqs/1WRL_A_seqs.fasta
# done
# cluster_seqs/3TU1_A_seqs.fasta
# done
# cluster_seqs/6PB1_U_seqs.fasta
# done
# cluster_seqs/1U96_A_seqs.fasta
# done
# cluster_seqs/2K1S_A_seqs.fasta
# done
# cluster_seqs/6O8D_L_seqs.fasta
# done
# cluster_seqs/3ROV_B_seqs.fasta
# done
# cluster_seqs/2LG5_A_seqs.fasta
# done
# cluster_seqs/2KVU_A_seqs.fasta
# done
# cluster_seqs/2UZI_L_seqs.fasta
# done
# cluster_seqs/6RH5_A_seqs.fasta
# done
# cluster_seqs/1VND_A_seqs.fasta
# done
# cluster_seqs/4TMA_I_seqs.fasta
# done
# cluster_seqs/2DPR_A_seqs.fasta
# done
# cluster_seqs/3FN1_A_seqs.fasta
# done
# cluster_seqs/2RMO_A_seqs.fasta
# done
# cluster_seqs/1S4W_A_seqs.fasta
# done
# cluster_seqs/2ELN_A_seqs.fasta
# done
# cluster_seqs/2N1C_A_seqs.fasta
# done
# cluster_seqs/1WKX_A_seqs.fasta
# done
# cluster_seqs/1DUJ_A_seqs.fasta
# done
# cluster_seqs/1DFN_A_seqs.fasta
# done
# cluster_seqs/2A4J_A_seqs.fasta
# done
# cluster_seqs/2KAY_A_seqs.fasta
# done
# cluster_seqs/2MP5_1_seqs.fasta
# done
# cluster_seqs/6PSI_B_seqs.fasta
# done
# cluster_seqs/2JY5_A_seqs.fasta
# done
# cluster_seqs/1SUY_C_seqs.fasta
# done
# cluster_seqs/2N05_A_seqs.fasta
# done
# cluster_seqs/5K89_A_seqs.fasta
# done
# cluster_seqs/1F3Y_A_seqs.fasta
# done
# cluster_seqs/6Y8W_A_seqs.fasta
# done
# cluster_seqs/2SAK_A_seqs.fasta
# done
# cluster_seqs/3TMH_A_seqs.fasta
# done
# cluster_seqs/2MU1_A_seqs.fasta
# done
# cluster_seqs/6TR0_A_seqs.fasta
# done
# cluster_seqs/2Q98_A_seqs.fasta
# done
# cluster_seqs/4UET_A_seqs.fasta
# done
# cluster_seqs/1DEF_A_seqs.fasta
# done
# cluster_seqs/1GBQ_A_seqs.fasta
# done
# cluster_seqs/3NCU_A_seqs.fasta
# done
# cluster_seqs/2Q3P_A_seqs.fasta
# done
# cluster_seqs/4DMD_A_seqs.fasta
# done
# cluster_seqs/2R6C_G_seqs.fasta
# done
# cluster_seqs/3CPK_A_seqs.fasta
# done
# cluster_seqs/4JI0_P_seqs.fasta
# done
# cluster_seqs/1KTU_A_seqs.fasta
# done
# cluster_seqs/6ZZE_A_seqs.fasta
# done
# cluster_seqs/4Q3H_A_seqs.fasta
# done
# cluster_seqs/2MKF_A_seqs.fasta
# done
# cluster_seqs/2KZY_A_seqs.fasta
# done
# cluster_seqs/2KQD_A_seqs.fasta
# done
# cluster_seqs/1U8B_A_seqs.fasta
# done
# cluster_seqs/1XXE_A_seqs.fasta
# done
# cluster_seqs/2HRN_A_seqs.fasta
# done
# cluster_seqs/2RU3_A_seqs.fasta
# done
# cluster_seqs/2JWA_A_seqs.fasta
# done
# cluster_seqs/1NMN_A_seqs.fasta
# done
# cluster_seqs/1FDM_A_seqs.fasta
# done
# cluster_seqs/2XMM_A_seqs.fasta
# done
# cluster_seqs/2PSP_A_seqs.fasta
# done
# cluster_seqs/2FWL_B_seqs.fasta
# done
# cluster_seqs/2KA9_A_seqs.fasta
# done
# cluster_seqs/1YH5_A_seqs.fasta
# done
# cluster_seqs/2MKZ_A_seqs.fasta
# done
# cluster_seqs/1BJB_A_seqs.fasta
# done
# cluster_seqs/2LFN_A_seqs.fasta
# done
# cluster_seqs/2LM5_A_seqs.fasta
# done
# cluster_seqs/2A3S_A_seqs.fasta
# done
# cluster_seqs/2NBD_A_seqs.fasta
# done
# cluster_seqs/1H0A_A_seqs.fasta
# done
# cluster_seqs/2FK4_A_seqs.fasta
# done
# cluster_seqs/2JYU_A_seqs.fasta
# done
# cluster_seqs/2H5M_A_seqs.fasta
# done
# cluster_seqs/1E6E_B_seqs.fasta
# done
# cluster_seqs/2MOZ_A_seqs.fasta
# done
# cluster_seqs/2KR2_A_seqs.fasta
# done
# cluster_seqs/1E88_A_seqs.fasta
# done
# cluster_seqs/2HM4_A_seqs.fasta
# done
# cluster_seqs/1SRZ_A_seqs.fasta
# done
# cluster_seqs/2JP1_A_seqs.fasta
# done
# cluster_seqs/1Q02_A_seqs.fasta
# done
# cluster_seqs/2LE8_A_seqs.fasta
# done
# cluster_seqs/7AT7_A_seqs.fasta
# done
# cluster_seqs/2KIO_A_seqs.fasta
# done
# cluster_seqs/6X7D_A_seqs.fasta
# done
# cluster_seqs/4KL6_A_seqs.fasta
# done
# cluster_seqs/1H92_A_seqs.fasta
# done
# cluster_seqs/1B5N_A_seqs.fasta
# done
# cluster_seqs/3VTU_A_seqs.fasta
# done
# cluster_seqs/1F2R_C_seqs.fasta
# done
# cluster_seqs/1N5H_A_seqs.fasta
# done
# cluster_seqs/2RRH_A_seqs.fasta
# done
# cluster_seqs/3W96_C_seqs.fasta
# done
# cluster_seqs/4XJK_B_seqs.fasta
# done
# cluster_seqs/3FZB_A_seqs.fasta
# done
# cluster_seqs/2RV5_A_seqs.fasta
# done
# cluster_seqs/4MZT_A_seqs.fasta
# done
# cluster_seqs/2C0L_B_seqs.fasta
# done
# cluster_seqs/3QVG_A_seqs.fasta
# done
# cluster_seqs/3TGX_B_seqs.fasta
# done
# cluster_seqs/1ZDA_A_seqs.fasta
# done
# cluster_seqs/7KRB_A_seqs.fasta
# done
# cluster_seqs/2F08_A_seqs.fasta
# done
# cluster_seqs/1E3O_C_seqs.fasta
# done
# cluster_seqs/2YW8_A_seqs.fasta
# done
# cluster_seqs/6XGV_B_seqs.fasta
# done
# cluster_seqs/6S1U_A_seqs.fasta
# done
# cluster_seqs/1JOY_A_seqs.fasta
# done
# cluster_seqs/2KEN_A_seqs.fasta
# done
# cluster_seqs/2H9E_C_seqs.fasta
# done
# cluster_seqs/5XO5_A_seqs.fasta
# done
# cluster_seqs/3KW6_A_seqs.fasta
# done
# cluster_seqs/1OSX_A_seqs.fasta
# done
# cluster_seqs/1SB0_B_seqs.fasta
# done
# cluster_seqs/1ODB_A_seqs.fasta
# done
# cluster_seqs/1BON_B_seqs.fasta
# done
# cluster_seqs/1T1Q_B_seqs.fasta
# done
# cluster_seqs/1J7R_A_seqs.fasta
# done
# cluster_seqs/2MUT_B_seqs.fasta
# done
# cluster_seqs/2VY5_A_seqs.fasta
# done
# cluster_seqs/1UMS_A_seqs.fasta
# done
# cluster_seqs/2I59_A_seqs.fasta
# done
# cluster_seqs/2FB7_A_seqs.fasta
# done
# cluster_seqs/2MRE_B_seqs.fasta
# done
# cluster_seqs/1B9Q_A_seqs.fasta
# done
# cluster_seqs/1AG2_A_seqs.fasta
# done
# cluster_seqs/1CEW_I_seqs.fasta
# done
# cluster_seqs/1AGG_A_seqs.fasta
# done
# cluster_seqs/3L73_E_seqs.fasta
# done
# cluster_seqs/2L62_A_seqs.fasta
# done
# cluster_seqs/1IP9_A_seqs.fasta
# done
# cluster_seqs/5CSF_A_seqs.fasta
# done
# cluster_seqs/2YRD_A_seqs.fasta
# done
# cluster_seqs/1QGB_A_seqs.fasta
# done
# cluster_seqs/1C3Y_A_seqs.fasta
# done
# cluster_seqs/2I2Y_A_seqs.fasta
# done
# cluster_seqs/6HE6_A_seqs.fasta
# done
# cluster_seqs/1OWA_A_seqs.fasta
# done
# cluster_seqs/6O6I_A_seqs.fasta
# done
# cluster_seqs/2KCZ_A_seqs.fasta
# done
# cluster_seqs/2YUI_A_seqs.fasta
# done
# cluster_seqs/2L75_A_seqs.fasta
# done
# cluster_seqs/6KZF_B_seqs.fasta
# done
# cluster_seqs/2FCW_A_seqs.fasta
# done
# cluster_seqs/1MVK_A_seqs.fasta
# done
# cluster_seqs/2LC6_A_seqs.fasta
# done
# cluster_seqs/1BO0_A_seqs.fasta
# done
# cluster_seqs/1H7I_A_seqs.fasta
# done
# cluster_seqs/2MMH_A_seqs.fasta
# done
# cluster_seqs/6W2G_A_seqs.fasta
# done
# cluster_seqs/2KX0_A_seqs.fasta
# done
# cluster_seqs/4WOL_A_seqs.fasta
# done
# cluster_seqs/6SVK_A_seqs.fasta
# done
# cluster_seqs/2KPA_A_seqs.fasta
# done
# cluster_seqs/1VFC_A_seqs.fasta
# done
# cluster_seqs/3D7C_A_seqs.fasta
# done
# cluster_seqs/1KVN_A_seqs.fasta
# done
# cluster_seqs/1JXP_A_seqs.fasta
# done
# cluster_seqs/3BK3_C_seqs.fasta
# done
# cluster_seqs/6SO9_A_seqs.fasta
# done
# cluster_seqs/2L9I_A_seqs.fasta
# done
# cluster_seqs/4O9B_A_seqs.fasta
# done
# cluster_seqs/6J9F_J_seqs.fasta
# done
# cluster_seqs/2L83_A_seqs.fasta
# done
# cluster_seqs/3GL6_A_seqs.fasta
# done
# cluster_seqs/1IFC_A_seqs.fasta
# done
# cluster_seqs/4XKL_B_seqs.fasta
# done
# cluster_seqs/3GCX_E_seqs.fasta
# done
# cluster_seqs/3CH5_B_seqs.fasta
# done
# cluster_seqs/1SCV_A_seqs.fasta
# done
# cluster_seqs/1KJS_A_seqs.fasta
# done
# cluster_seqs/4J6P_A_seqs.fasta
# done
# cluster_seqs/1Q5W_A_seqs.fasta
# done
# cluster_seqs/2MLM_A_seqs.fasta
# done
# cluster_seqs/1QP3_A_seqs.fasta
# done
# cluster_seqs/1F4I_A_seqs.fasta
# done
# cluster_seqs/1EIH_A_seqs.fasta
# done
# cluster_seqs/1BBN_A_seqs.fasta
# done
# cluster_seqs/2MSK_A_seqs.fasta
# done
# cluster_seqs/5L6W_C_seqs.fasta
# done
# cluster_seqs/2LB3_A_seqs.fasta
# done
# cluster_seqs/6WA4_A_seqs.fasta
# done
# cluster_seqs/5GAJ_A_seqs.fasta
# done
# cluster_seqs/1QWV_A_seqs.fasta
# done
# cluster_seqs/4TLQ_A_seqs.fasta
# done
# cluster_seqs/1A62_A_seqs.fasta
# done
# cluster_seqs/1ZZK_A_seqs.fasta
# done
# cluster_seqs/2N97_A_seqs.fasta
# done
# cluster_seqs/6YI3_A_seqs.fasta
# done
# cluster_seqs/1QTU_A_seqs.fasta
# done
# cluster_seqs/2X04_A_seqs.fasta
# done
# cluster_seqs/2N9O_A_seqs.fasta
# done
# cluster_seqs/4GV5_A_seqs.fasta
# done
# cluster_seqs/2JZF_A_seqs.fasta
# done
# cluster_seqs/3OFH_A_seqs.fasta
# done
# cluster_seqs/1DGZ_A_seqs.fasta
# done
# cluster_seqs/2W51_A_seqs.fasta
# done
# cluster_seqs/2LP7_A_seqs.fasta
# done
# cluster_seqs/3EVX_A_seqs.fasta
# done
# cluster_seqs/6XFL_A_seqs.fasta
# done
# cluster_seqs/4G28_B_seqs.fasta
# done
# cluster_seqs/2ROZ_A_seqs.fasta
# done
# cluster_seqs/4QCJ_A_seqs.fasta
# done
# cluster_seqs/2JCN_A_seqs.fasta
# done
# cluster_seqs/6UCJ_A_seqs.fasta
# done
# cluster_seqs/6E28_C_seqs.fasta
# done
# cluster_seqs/1AHD_P_seqs.fasta
# done
# cluster_seqs/3HD7_B_seqs.fasta
# done
# cluster_seqs/1YWU_A_seqs.fasta
# done
# cluster_seqs/2MR7_A_seqs.fasta
# done
# cluster_seqs/5YXM_A_seqs.fasta
# done
# cluster_seqs/1T4Z_A_seqs.fasta
# done
# cluster_seqs/2JM6_B_seqs.fasta
# done
# cluster_seqs/2XCJ_A_seqs.fasta
# done
# cluster_seqs/1FJE_B_seqs.fasta
# done
# cluster_seqs/3OSJ_A_seqs.fasta
# done
# cluster_seqs/6C2V_A_seqs.fasta
# done
# cluster_seqs/3WE3_A_seqs.fasta
# done
# cluster_seqs/2MJE_A_seqs.fasta
# done
# cluster_seqs/5Y95_A_seqs.fasta
# done
# cluster_seqs/2LJ1_A_seqs.fasta
# done
# cluster_seqs/1XAK_A_seqs.fasta
# done
# cluster_seqs/4OYD_A_seqs.fasta
# done
# cluster_seqs/1J2M_A_seqs.fasta
# done
# cluster_seqs/2LVI_A_seqs.fasta
# done
# cluster_seqs/6N4Q_E_seqs.fasta
# done
# cluster_seqs/1ZUG_A_seqs.fasta
# done
# cluster_seqs/1AY9_A_seqs.fasta
# done
# cluster_seqs/1LFB_A_seqs.fasta
# done
# cluster_seqs/1Y3J_A_seqs.fasta
# done
# cluster_seqs/1XN8_A_seqs.fasta
# done
# cluster_seqs/1VDY_A_seqs.fasta
# done
# cluster_seqs/2N4E_A_seqs.fasta
# done
# cluster_seqs/1C0C_A_seqs.fasta
# done
# cluster_seqs/2RSF_A_seqs.fasta
# done
# cluster_seqs/5CKT_D_seqs.fasta
# done
# cluster_seqs/2ELT_A_seqs.fasta
# done
# cluster_seqs/2CZO_A_seqs.fasta
# done
# cluster_seqs/1GP8_A_seqs.fasta
# done
# cluster_seqs/6HLV_B_seqs.fasta
# done
# cluster_seqs/2LEX_A_seqs.fasta
# done
# cluster_seqs/1AWX_A_seqs.fasta
# done
# cluster_seqs/2JW8_A_seqs.fasta
# done
# cluster_seqs/2N5M_A_seqs.fasta
# done
# cluster_seqs/3NVM_A_seqs.fasta
# done
# cluster_seqs/2LKT_A_seqs.fasta
# done
# cluster_seqs/5B7A_A_seqs.fasta
# done
# cluster_seqs/2BCC_E_seqs.fasta
# done
# cluster_seqs/6HGE_D_seqs.fasta
# done
# cluster_seqs/2LCX_A_seqs.fasta
# done
# cluster_seqs/1H7Y_A_seqs.fasta
# done
# cluster_seqs/6PVR_A_seqs.fasta
# done
# cluster_seqs/1Q6B_A_seqs.fasta
# done
# cluster_seqs/1TIH_A_seqs.fasta
# done
# cluster_seqs/2L5J_A_seqs.fasta
# done
# cluster_seqs/1KUP_B_seqs.fasta
# done
# cluster_seqs/1EMO_A_seqs.fasta
# done
# cluster_seqs/1K3J_A_seqs.fasta
# done
# cluster_seqs/2M5E_B_seqs.fasta
# done
# cluster_seqs/1TBO_A_seqs.fasta
# done
# cluster_seqs/1URQ_B_seqs.fasta
# done
# cluster_seqs/2KL8_A_seqs.fasta
# done
# cluster_seqs/6R4W_A_seqs.fasta
# done
# cluster_seqs/4FIB_A_seqs.fasta
# done
# cluster_seqs/6B0O_A_seqs.fasta
# done
# cluster_seqs/2G46_A_seqs.fasta
# done
# cluster_seqs/1PD7_A_seqs.fasta
# done
# cluster_seqs/2N49_A_seqs.fasta
# done
# cluster_seqs/2M0B_A_seqs.fasta
# done
# cluster_seqs/2LXB_A_seqs.fasta
# done
# cluster_seqs/1MP6_A_seqs.fasta
# done
# cluster_seqs/2RQW_A_seqs.fasta
# done
# cluster_seqs/4LWC_A_seqs.fasta
# done
# cluster_seqs/3LI6_A_seqs.fasta
# done
# cluster_seqs/2J4N_A_seqs.fasta
# done
# cluster_seqs/4BSX_A_seqs.fasta
# done
# cluster_seqs/2LO6_A_seqs.fasta
# done
# cluster_seqs/4J4G_A_seqs.fasta
# done
# cluster_seqs/1L1M_A_seqs.fasta
# done
# cluster_seqs/1PFM_A_seqs.fasta
# done
# cluster_seqs/7DC8_C_seqs.fasta
# done
# cluster_seqs/2GLH_A_seqs.fasta
# done
# cluster_seqs/2KGB_I_seqs.fasta
# done
# cluster_seqs/1P82_A_seqs.fasta
# done
# cluster_seqs/1X5B_A_seqs.fasta
# done
# cluster_seqs/6O83_B_seqs.fasta
# done
# cluster_seqs/2PQ4_A_seqs.fasta
# done
# cluster_seqs/2WO3_A_seqs.fasta
# done
# cluster_seqs/2MBL_A_seqs.fasta
# done
# cluster_seqs/2MKC_A_seqs.fasta
# done
# cluster_seqs/1BDV_A_seqs.fasta
# done
# cluster_seqs/1MUT_A_seqs.fasta
# done
# cluster_seqs/3EZQ_A_seqs.fasta
# done
# cluster_seqs/1HPH_A_seqs.fasta
# done
# cluster_seqs/2JMZ_A_seqs.fasta
# done
# cluster_seqs/1P1T_A_seqs.fasta
# done
# cluster_seqs/1SHC_A_seqs.fasta
# done
# cluster_seqs/7JXG_A_seqs.fasta
# done
# cluster_seqs/6U4N_A_seqs.fasta
# done
# cluster_seqs/2KLB_A_seqs.fasta
# done
# cluster_seqs/2NCY_A_seqs.fasta
# done
# cluster_seqs/2LD5_A_seqs.fasta
# done
# cluster_seqs/5YTX_A_seqs.fasta
# done
# cluster_seqs/2LCI_A_seqs.fasta
# done
# cluster_seqs/2Y28_A_seqs.fasta
# done
# cluster_seqs/1W0T_A_seqs.fasta
# done
# cluster_seqs/1RZW_A_seqs.fasta
# done
# cluster_seqs/1G2T_A_seqs.fasta
# done
# cluster_seqs/1SPY_A_seqs.fasta
# done
# cluster_seqs/6G04_A_seqs.fasta
# done
# cluster_seqs/4NCV_A_seqs.fasta
# done
# cluster_seqs/1XFQ_A_seqs.fasta
# done
# cluster_seqs/2L4X_A_seqs.fasta
# done
# cluster_seqs/2G0K_A_seqs.fasta
# done
# cluster_seqs/2DEZ_A_seqs.fasta
# done
# cluster_seqs/1RO3_A_seqs.fasta
# done
# cluster_seqs/1WNK_A_seqs.fasta
# done
# cluster_seqs/2LVB_A_seqs.fasta
# done
# cluster_seqs/2KA1_A_seqs.fasta
# done
# cluster_seqs/1X3Q_A_seqs.fasta
# done
# cluster_seqs/6BGH_A_seqs.fasta
# done
# cluster_seqs/2L7S_A_seqs.fasta
# done
# cluster_seqs/1VD7_A_seqs.fasta
# done
# cluster_seqs/6UZ5_B_seqs.fasta
# done
# cluster_seqs/2KDF_A_seqs.fasta
# done
# cluster_seqs/1W4H_A_seqs.fasta
# done
# cluster_seqs/2MD7_B_seqs.fasta
# done
# cluster_seqs/1RET_A_seqs.fasta
# done
# cluster_seqs/6DO6_A_seqs.fasta
# done
# cluster_seqs/4UZR_A_seqs.fasta
# done
# cluster_seqs/1Z2X_A_seqs.fasta
# done
# cluster_seqs/2DGO_A_seqs.fasta
# done
# cluster_seqs/2LTT_A_seqs.fasta
# done
# cluster_seqs/2AIN_A_seqs.fasta
# done
# cluster_seqs/5D1M_A_seqs.fasta
# done
# cluster_seqs/1PQS_A_seqs.fasta
# done
# cluster_seqs/2AGA_A_seqs.fasta
# done
# cluster_seqs/1Z1V_A_seqs.fasta
# done
# cluster_seqs/5KEG_A_seqs.fasta
# done
# cluster_seqs/1DNY_A_seqs.fasta
# done
# cluster_seqs/3ODE_A_seqs.fasta
# done
# cluster_seqs/2LZJ_A_seqs.fasta
# done
# cluster_seqs/2L3P_A_seqs.fasta
# done
# cluster_seqs/5LGF_A_seqs.fasta
# done
# cluster_seqs/2KQL_A_seqs.fasta
# done
# cluster_seqs/2LMV_A_seqs.fasta
# done
# cluster_seqs/2LLX_A_seqs.fasta
# done
# cluster_seqs/5IQQ_A_seqs.fasta
# done
# cluster_seqs/5Y22_A_seqs.fasta
# done
# cluster_seqs/5Z5Q_A_seqs.fasta
# done
# cluster_seqs/6S3W_A_seqs.fasta
# done
# cluster_seqs/2HH3_A_seqs.fasta
# done
# cluster_seqs/1VET_B_seqs.fasta
# done
# cluster_seqs/2L8J_A_seqs.fasta
# done
# cluster_seqs/2L05_A_seqs.fasta
# done
# cluster_seqs/2EEE_A_seqs.fasta
# done
# cluster_seqs/2LE2_A_seqs.fasta
# done
# cluster_seqs/5I5B_B_seqs.fasta
# done
# cluster_seqs/1K9R_A_seqs.fasta
# done
# cluster_seqs/5Y0D_B_seqs.fasta
# done
# cluster_seqs/1AP0_A_seqs.fasta
# done
# cluster_seqs/2H80_A_seqs.fasta
# done
# cluster_seqs/2M98_A_seqs.fasta
# done
# cluster_seqs/3CYI_A_seqs.fasta
# done
# cluster_seqs/1B21_A_seqs.fasta
# done
# cluster_seqs/2LM7_A_seqs.fasta
# done
# cluster_seqs/4F2E_A_seqs.fasta
# done
# cluster_seqs/2LTH_A_seqs.fasta
# done
# cluster_seqs/2L6S_A_seqs.fasta
# done
# cluster_seqs/1IJA_A_seqs.fasta
# done
# cluster_seqs/6FBQ_A_seqs.fasta
# done
# cluster_seqs/2LNS_A_seqs.fasta
# done
# cluster_seqs/1G04_A_seqs.fasta
# done
# cluster_seqs/2MM9_A_seqs.fasta
# done
# cluster_seqs/2GJ9_A_seqs.fasta
# done
# cluster_seqs/1U3N_A_seqs.fasta
# done
# cluster_seqs/2MSE_A_seqs.fasta
# done
# cluster_seqs/1FJK_A_seqs.fasta
# done
# cluster_seqs/1QLZ_A_seqs.fasta
# done
# cluster_seqs/2IPR_A_seqs.fasta
# done
# cluster_seqs/2MGW_A_seqs.fasta
# done
# cluster_seqs/1BNO_A_seqs.fasta
# done
# cluster_seqs/5YPY_A_seqs.fasta
# done
# cluster_seqs/2VIT_B_seqs.fasta
# done
# cluster_seqs/2LY4_A_seqs.fasta
# done
# cluster_seqs/2K9R_B_seqs.fasta
# done
# cluster_seqs/3H9X_A_seqs.fasta
# done
# cluster_seqs/3WSO_B_seqs.fasta
# done
# cluster_seqs/1EJP_A_seqs.fasta
# done
# cluster_seqs/5WLB_A_seqs.fasta
# done
# cluster_seqs/1JZU_A_seqs.fasta
# done
# cluster_seqs/6U0J_B_seqs.fasta
# done
# cluster_seqs/2YKA_A_seqs.fasta
# done
# cluster_seqs/2DJJ_A_seqs.fasta
# done
# cluster_seqs/2RCZ_A_seqs.fasta
# done
# cluster_seqs/6QFP_A_seqs.fasta
# done
# cluster_seqs/2L36_A_seqs.fasta
# done
# cluster_seqs/1IWF_A_seqs.fasta
# done
# cluster_seqs/2LIQ_A_seqs.fasta
# done
# cluster_seqs/1HRF_A_seqs.fasta
# done
# cluster_seqs/2L6R_A_seqs.fasta
# done
# cluster_seqs/1CKW_A_seqs.fasta
# done
# cluster_seqs/2JX2_A_seqs.fasta
# done
# cluster_seqs/1A1T_A_seqs.fasta
# done
# cluster_seqs/1AN1_I_seqs.fasta
# done
# cluster_seqs/2JQM_A_seqs.fasta
# done
# cluster_seqs/1HUM_A_seqs.fasta
# done
# cluster_seqs/1Q2F_A_seqs.fasta
# done
# cluster_seqs/1ACI_A_seqs.fasta
# done
# cluster_seqs/6TD4_A_seqs.fasta
# done
# cluster_seqs/6TJV_Q_seqs.fasta
# done
# cluster_seqs/2RS9_B_seqs.fasta
# done
# cluster_seqs/2Z31_A_seqs.fasta
# done
# cluster_seqs/2KQY_A_seqs.fasta
# done
# cluster_seqs/2NCS_A_seqs.fasta
# done
# cluster_seqs/2NZZ_A_seqs.fasta
# done
# cluster_seqs/2RPW_X_seqs.fasta
# done
# cluster_seqs/6I7R_C_seqs.fasta
# done
# cluster_seqs/2KJO_A_seqs.fasta
# done
# cluster_seqs/1VYC_A_seqs.fasta
# done
# cluster_seqs/1C7V_A_seqs.fasta
# done
# cluster_seqs/2GE4_A_seqs.fasta
# done
# cluster_seqs/1ITY_A_seqs.fasta
# done
# cluster_seqs/4KG3_A_seqs.fasta
# done
# cluster_seqs/2LIW_A_seqs.fasta
# done
# cluster_seqs/1WWW_X_seqs.fasta
# done
# cluster_seqs/1VD8_A_seqs.fasta
# done
# cluster_seqs/4FAO_C_seqs.fasta
# done
# cluster_seqs/2RO4_A_seqs.fasta
# done
# cluster_seqs/5UY2_A_seqs.fasta
# done
# cluster_seqs/1WYL_A_seqs.fasta
# done
# cluster_seqs/2KC8_A_seqs.fasta
# done
# cluster_seqs/1IRG_A_seqs.fasta
# done
# cluster_seqs/4K44_A_seqs.fasta
# done
# cluster_seqs/2OEH_A_seqs.fasta
# done
# cluster_seqs/1IOG_B_seqs.fasta
# done
# cluster_seqs/2LK0_A_seqs.fasta
# done
# cluster_seqs/6QQ7_A_seqs.fasta
# done
# cluster_seqs/4TMP_A_seqs.fasta
# done
# cluster_seqs/2KN1_A_seqs.fasta
# done
# cluster_seqs/1PMX_A_seqs.fasta
# done
# cluster_seqs/2JR0_A_seqs.fasta
# done
# cluster_seqs/6PRI_A_seqs.fasta
# done
# cluster_seqs/2LA6_A_seqs.fasta
# done
# cluster_seqs/1ZRW_A_seqs.fasta
# done
# cluster_seqs/4AA6_A_seqs.fasta
# done
# cluster_seqs/1GO9_A_seqs.fasta
# done
# cluster_seqs/4FOF_A_seqs.fasta
# done
# cluster_seqs/1RO4_A_seqs.fasta
# done
# cluster_seqs/1F0G_A_seqs.fasta
# done
# cluster_seqs/2RUT_A_seqs.fasta
# done
# cluster_seqs/4YII_A_seqs.fasta
# done
# cluster_seqs/6YBW_q_seqs.fasta
# done
# cluster_seqs/2MEY_A_seqs.fasta
# done
# cluster_seqs/2GO0_A_seqs.fasta
# done
# cluster_seqs/2WUL_A_seqs.fasta
# done
# cluster_seqs/1WGU_A_seqs.fasta
# done
# cluster_seqs/2MQM_A_seqs.fasta
# done
# cluster_seqs/2JV5_A_seqs.fasta
# done
# cluster_seqs/1HDL_A_seqs.fasta
# done
# cluster_seqs/6QZB_A_seqs.fasta
# done
# cluster_seqs/4CH1_A_seqs.fasta
# done
# cluster_seqs/1TBC_A_seqs.fasta
# done
# cluster_seqs/1J55_A_seqs.fasta
# done
# cluster_seqs/2AOB_A_seqs.fasta
# done
# cluster_seqs/1W9G_A_seqs.fasta
# done
# cluster_seqs/1YUR_A_seqs.fasta
# done
# cluster_seqs/1WM4_A_seqs.fasta
# done
# cluster_seqs/1YUF_A_seqs.fasta
# done
# cluster_seqs/1R7E_A_seqs.fasta
# done
# cluster_seqs/2XDI_A_seqs.fasta
# done
# cluster_seqs/2JTT_A_seqs.fasta
# done
# cluster_seqs/1WQC_A_seqs.fasta
# done
# cluster_seqs/4GLS_C_seqs.fasta
# done
# cluster_seqs/1G1P_A_seqs.fasta
# done
# cluster_seqs/4FPW_A_seqs.fasta
# done
# cluster_seqs/1NIW_B_seqs.fasta
# done
# cluster_seqs/5CJP_A_seqs.fasta
# done
# cluster_seqs/2RV0_A_seqs.fasta
# done
# cluster_seqs/1C89_A_seqs.fasta
# done
# cluster_seqs/1X50_A_seqs.fasta
# done
# cluster_seqs/1POZ_A_seqs.fasta
# done
# cluster_seqs/2JQL_A_seqs.fasta
# done
# cluster_seqs/2LAT_A_seqs.fasta
# done
# cluster_seqs/1QOJ_A_seqs.fasta
# done
# cluster_seqs/2KKO_A_seqs.fasta
# done
# cluster_seqs/6IB6_A_seqs.fasta
# done
# cluster_seqs/2LCY_A_seqs.fasta
# done
# cluster_seqs/5X37_A_seqs.fasta
# done
# cluster_seqs/2LTR_A_seqs.fasta
# done
# cluster_seqs/6N2M_A_seqs.fasta
# done
# cluster_seqs/2KXC_A_seqs.fasta
# done
# cluster_seqs/6WX8_B_seqs.fasta
# done
# cluster_seqs/2LOH_A_seqs.fasta
# done
# cluster_seqs/6GDK_A_seqs.fasta
# done
# cluster_seqs/2RVQ_D_seqs.fasta
# done
# cluster_seqs/2MZ1_A_seqs.fasta
# done
# cluster_seqs/2HNB_A_seqs.fasta
# done
# cluster_seqs/1JN7_A_seqs.fasta
# done
# cluster_seqs/2MD5_A_seqs.fasta
# done
# cluster_seqs/2L7I_A_seqs.fasta
# done
# cluster_seqs/1QA4_A_seqs.fasta
# done
# cluster_seqs/4NC7_A_seqs.fasta
# done
# cluster_seqs/1PRU_A_seqs.fasta
# done
# cluster_seqs/2MUY_A_seqs.fasta
# done
# cluster_seqs/2KYQ_A_seqs.fasta
# done
# cluster_seqs/2KW2_A_seqs.fasta
# done
# cluster_seqs/6JIQ_A_seqs.fasta
# done
# cluster_seqs/1I5J_A_seqs.fasta
# done
# cluster_seqs/2JOU_A_seqs.fasta
# done
# cluster_seqs/1A6S_A_seqs.fasta
# done
# cluster_seqs/3U28_B_seqs.fasta
# done
# cluster_seqs/2LKH_A_seqs.fasta
# done
# cluster_seqs/2JM1_A_seqs.fasta
# done
# cluster_seqs/2JT8_A_seqs.fasta
# done
# cluster_seqs/1JYT_A_seqs.fasta
# done
# cluster_seqs/2KQ2_A_seqs.fasta
# done
# cluster_seqs/2JMW_A_seqs.fasta
# done
# cluster_seqs/1EXE_A_seqs.fasta
# done
# cluster_seqs/2PNI_A_seqs.fasta
# done
# cluster_seqs/1IVA_A_seqs.fasta
# done
# cluster_seqs/1SP7_A_seqs.fasta
# done
# cluster_seqs/2K7D_A_seqs.fasta
# done
# cluster_seqs/1R02_A_seqs.fasta
# done
# cluster_seqs/1TQC_A_seqs.fasta
# done
# cluster_seqs/2DCR_A_seqs.fasta
# done
# cluster_seqs/2L5N_A_seqs.fasta
# done
# cluster_seqs/2ND0_A_seqs.fasta
# done
# cluster_seqs/2LTI_A_seqs.fasta
# done
# cluster_seqs/5FJ4_A_seqs.fasta
# done
# cluster_seqs/1W0A_A_seqs.fasta
# done
# cluster_seqs/6YP9_B_seqs.fasta
# done
# cluster_seqs/3N52_A_seqs.fasta
# done
# cluster_seqs/2YU7_A_seqs.fasta
# done
# cluster_seqs/2N7C_A_seqs.fasta
# done
# cluster_seqs/5E10_A_seqs.fasta
# done
# cluster_seqs/2L4E_A_seqs.fasta
# done
# cluster_seqs/1T3V_A_seqs.fasta
# done
# cluster_seqs/2J0T_A_seqs.fasta
# done
# cluster_seqs/2HGM_A_seqs.fasta
# done
# cluster_seqs/1YIU_A_seqs.fasta
# done
# cluster_seqs/3QRC_A_seqs.fasta
# done
# cluster_seqs/6O9Z_L_seqs.fasta
# done
# cluster_seqs/1EDJ_A_seqs.fasta
# done
# cluster_seqs/1TXB_A_seqs.fasta
# done
# cluster_seqs/2RV2_A_seqs.fasta
# done
# cluster_seqs/7D16_A_seqs.fasta
# done
# cluster_seqs/2ADL_A_seqs.fasta
# done
# cluster_seqs/1VDI_A_seqs.fasta
# done
# cluster_seqs/2EZL_A_seqs.fasta
# done
# cluster_seqs/2K28_A_seqs.fasta
# done
# cluster_seqs/6TQO_G_seqs.fasta
# done
# cluster_seqs/2M1I_A_seqs.fasta
# done
# cluster_seqs/2KEG_A_seqs.fasta
# done
# cluster_seqs/2AI5_A_seqs.fasta
# done
# cluster_seqs/2KXW_A_seqs.fasta
# done
# cluster_seqs/3Q69_A_seqs.fasta
# done
# cluster_seqs/7A1G_N_seqs.fasta
# done
# cluster_seqs/2HDZ_A_seqs.fasta
# done
# cluster_seqs/2MGY_A_seqs.fasta
# done
# cluster_seqs/4BD3_A_seqs.fasta
# done
# cluster_seqs/2KWB_A_seqs.fasta
# done
# cluster_seqs/2ELP_A_seqs.fasta
# done
# cluster_seqs/2KSG_A_seqs.fasta
# done
# cluster_seqs/6GOV_B_seqs.fasta
# done
# cluster_seqs/2HH4_B_seqs.fasta
# done
# cluster_seqs/2LYA_A_seqs.fasta
# done
# cluster_seqs/2MFG_A_seqs.fasta
# done
# cluster_seqs/2KWX_A_seqs.fasta
# done
# cluster_seqs/2HP8_A_seqs.fasta
# done
# cluster_seqs/1T3W_A_seqs.fasta
# done
# cluster_seqs/6XCR_A_seqs.fasta
# done
# cluster_seqs/2MKD_A_seqs.fasta
# done
# cluster_seqs/3C4S_A_seqs.fasta
# done
# cluster_seqs/2BBM_B_seqs.fasta
# done
# cluster_seqs/1Q48_A_seqs.fasta
# done
# cluster_seqs/2ZEQ_A_seqs.fasta
# done
# cluster_seqs/1K0H_A_seqs.fasta
# done
# cluster_seqs/2MN7_A_seqs.fasta
# done
# cluster_seqs/2JPL_A_seqs.fasta
# done
# cluster_seqs/1YX7_A_seqs.fasta
# done
# cluster_seqs/5MF9_A_seqs.fasta
# done
# cluster_seqs/2H45_A_seqs.fasta
# done
# cluster_seqs/3IM4_A_seqs.fasta
# done
# cluster_seqs/4IC2_A_seqs.fasta
# done
# cluster_seqs/2KVB_A_seqs.fasta
# done
# cluster_seqs/2KSP_A_seqs.fasta
# done
# cluster_seqs/1CTX_A_seqs.fasta
# done
# cluster_seqs/6TS3_A_seqs.fasta
# done
# cluster_seqs/2MSV_A_seqs.fasta
# done
# cluster_seqs/2RRB_A_seqs.fasta
# done
# cluster_seqs/2IWG_A_seqs.fasta
# done
# cluster_seqs/5HYU_B_seqs.fasta
# done
# cluster_seqs/7JZV_B_seqs.fasta
# done
# cluster_seqs/2N4A_A_seqs.fasta
# done
# cluster_seqs/2W85_A_seqs.fasta
# done
# cluster_seqs/6JZV_A_seqs.fasta
# done
# cluster_seqs/1FW4_A_seqs.fasta
# done
# cluster_seqs/3V4J_A_seqs.fasta
# done
# cluster_seqs/6UFV_A_seqs.fasta
# done
# cluster_seqs/2LEB_A_seqs.fasta
# done
# cluster_seqs/4ASW_C_seqs.fasta
# done
# cluster_seqs/2KJD_A_seqs.fasta
# done
# cluster_seqs/2QPW_A_seqs.fasta
# done
# cluster_seqs/7B0Y_H_seqs.fasta
# done
# cluster_seqs/2JRH_A_seqs.fasta
# done
# cluster_seqs/2K32_A_seqs.fasta
# done
# cluster_seqs/4JPA_A_seqs.fasta
# done
# cluster_seqs/2RSJ_A_seqs.fasta
# done
# cluster_seqs/2HGL_A_seqs.fasta
# done
# cluster_seqs/2L79_A_seqs.fasta
# done
# cluster_seqs/2L86_A_seqs.fasta
# done
# cluster_seqs/5A7C_A_seqs.fasta
# done
# cluster_seqs/1SSU_A_seqs.fasta
# done
# cluster_seqs/2H3K_A_seqs.fasta
# done
# cluster_seqs/1K46_A_seqs.fasta
# done
# cluster_seqs/2F1V_A_seqs.fasta
# done
# cluster_seqs/2EQQ_A_seqs.fasta
# done
# cluster_seqs/3O1Y_A_seqs.fasta
# done
# cluster_seqs/5C2J_B_seqs.fasta
# done
# cluster_seqs/2MX6_A_seqs.fasta
# done
# cluster_seqs/3IOL_B_seqs.fasta
# done
# cluster_seqs/2LY2_A_seqs.fasta
# done
# cluster_seqs/2VNF_A_seqs.fasta
# done
# cluster_seqs/2KZT_A_seqs.fasta
# done
# cluster_seqs/1UXD_A_seqs.fasta
# done
# cluster_seqs/2EQH_A_seqs.fasta
# done
# cluster_seqs/4MMX_C_seqs.fasta
# done
# cluster_seqs/2MX9_A_seqs.fasta
# done
# cluster_seqs/1HSQ_A_seqs.fasta
# done
# cluster_seqs/2ME0_A_seqs.fasta
# done
# cluster_seqs/1ADN_A_seqs.fasta
# done
# cluster_seqs/5MXN_A_seqs.fasta
# done
# cluster_seqs/2GTO_A_seqs.fasta
# done
# cluster_seqs/2Z9T_A_seqs.fasta
# done
# cluster_seqs/1XOP_A_seqs.fasta
# done
# cluster_seqs/2HBB_A_seqs.fasta
# done
# cluster_seqs/2KNS_A_seqs.fasta
# done
# cluster_seqs/3A4C_A_seqs.fasta
# done
# cluster_seqs/1ON4_A_seqs.fasta
# done
# cluster_seqs/2JS7_A_seqs.fasta
# done
# cluster_seqs/2KCU_A_seqs.fasta
# done
# cluster_seqs/3DDR_C_seqs.fasta
# done
# cluster_seqs/6WBV_B_seqs.fasta
# done
# cluster_seqs/1L3E_B_seqs.fasta
# done
# cluster_seqs/2UZK_A_seqs.fasta
# done
# cluster_seqs/2XQQ_A_seqs.fasta
# done
# cluster_seqs/1M8O_B_seqs.fasta
# done
# cluster_seqs/3N7D_A_seqs.fasta
# done
# cluster_seqs/2J8J_A_seqs.fasta
# done
# cluster_seqs/2KLD_A_seqs.fasta
# done
# cluster_seqs/2N7Q_A_seqs.fasta
# done
# cluster_seqs/1ORM_A_seqs.fasta
# done
# cluster_seqs/2MOF_A_seqs.fasta
# done
# cluster_seqs/1P6R_A_seqs.fasta
# done
# cluster_seqs/2HGN_A_seqs.fasta
# done
# cluster_seqs/1Z6V_A_seqs.fasta
# done
# cluster_seqs/1LKJ_A_seqs.fasta
# done
# cluster_seqs/1ZUE_A_seqs.fasta
# done
# cluster_seqs/5LPU_C_seqs.fasta
# done
# cluster_seqs/6QK6_A_seqs.fasta
# done
# cluster_seqs/2LKM_A_seqs.fasta
# done
# cluster_seqs/5JYU_A_seqs.fasta
# done
# cluster_seqs/6CIM_N_seqs.fasta
# done
# cluster_seqs/2KUQ_A_seqs.fasta
# done
# cluster_seqs/2K8X_A_seqs.fasta
# done
# cluster_seqs/2MQO_A_seqs.fasta
# done
# cluster_seqs/2KMX_A_seqs.fasta
# done
# cluster_seqs/2B7V_A_seqs.fasta
# done
# cluster_seqs/2N7B_A_seqs.fasta
# done
# cluster_seqs/2K6T_A_seqs.fasta
# done
# cluster_seqs/6GAT_A_seqs.fasta
# done
# cluster_seqs/2JV3_A_seqs.fasta
# done
# cluster_seqs/1YSF_A_seqs.fasta
# done
# cluster_seqs/2MJZ_A_seqs.fasta
# done
# cluster_seqs/6AXQ_A_seqs.fasta
# done
# cluster_seqs/1T08_A_seqs.fasta
# done
# cluster_seqs/2LGE_A_seqs.fasta
# done
# cluster_seqs/1SH1_A_seqs.fasta
# done
# cluster_seqs/6V5L_A_seqs.fasta
# done
# cluster_seqs/1XWN_A_seqs.fasta
# done
# cluster_seqs/5DOW_A_seqs.fasta
# done
# cluster_seqs/1MFL_A_seqs.fasta
# done
# cluster_seqs/6YY3_G_seqs.fasta
# done
# cluster_seqs/2DH9_A_seqs.fasta
# done
# cluster_seqs/3PBP_B_seqs.fasta
# done
# cluster_seqs/5KY0_B_seqs.fasta
# done
# cluster_seqs/2W9U_A_seqs.fasta
# done
# cluster_seqs/1NQL_B_seqs.fasta
# done
# cluster_seqs/3S1B_V_seqs.fasta
# done
# cluster_seqs/1YX5_B_seqs.fasta
# done
# cluster_seqs/2H8W_A_seqs.fasta
# done
# cluster_seqs/4INW_A_seqs.fasta
# done
# cluster_seqs/1F54_A_seqs.fasta
# done
# cluster_seqs/1N88_A_seqs.fasta
# done
# cluster_seqs/1CFH_A_seqs.fasta
# done
# cluster_seqs/1V0A_A_seqs.fasta
# done
# cluster_seqs/1TNW_A_seqs.fasta
# done
# cluster_seqs/1CEJ_A_seqs.fasta
# done
# cluster_seqs/2M0T_A_seqs.fasta
# done
# cluster_seqs/5ZSY_A_seqs.fasta
# done
# cluster_seqs/2L63_A_seqs.fasta
# done
# cluster_seqs/1Y04_A_seqs.fasta
# done
# cluster_seqs/3HMT_A_seqs.fasta
# done
# cluster_seqs/1F43_A_seqs.fasta
# done
# cluster_seqs/1SE7_A_seqs.fasta
# done
# cluster_seqs/2K74_A_seqs.fasta
# done
# cluster_seqs/1A6X_A_seqs.fasta
# done
# cluster_seqs/2FUU_A_seqs.fasta
# done
# cluster_seqs/3ZVY_A_seqs.fasta
# done
# cluster_seqs/2LAN_A_seqs.fasta
# done
# cluster_seqs/1F9X_A_seqs.fasta
# done
# cluster_seqs/4J2J_A_seqs.fasta
# done
# cluster_seqs/2DRN_A_seqs.fasta
# done
# cluster_seqs/6ES5_A_seqs.fasta
# done
# cluster_seqs/2UVS_A_seqs.fasta
# done
# cluster_seqs/1Q68_B_seqs.fasta
# done
# cluster_seqs/2K7A_B_seqs.fasta
# done
# cluster_seqs/2M8I_A_seqs.fasta
# done
# cluster_seqs/7A58_A_seqs.fasta
# done
# cluster_seqs/2L0L_A_seqs.fasta
# done
# cluster_seqs/1A91_A_seqs.fasta
# done
# cluster_seqs/2ELW_A_seqs.fasta
# done
# cluster_seqs/2JU2_A_seqs.fasta
# done
# cluster_seqs/2K8V_A_seqs.fasta
# done
# cluster_seqs/1LB2_B_seqs.fasta
# done
# cluster_seqs/6OFF_A_seqs.fasta
# done
# cluster_seqs/2MQ8_A_seqs.fasta
# done
# ...
# done
# cluster_seqs/2JS1-11-B_seqs.fasta
# done
# cluster_seqs/2JS1-4-B_seqs.fasta
# done
# cluster_seqs/2JS1-3-B_seqs.fasta
# done
# cluster_seqs/2JS1--1-B_seqs.fasta
# done
# cluster_seqs/2JS1-3-A_seqs.fasta
# done
# cluster_seqs/2GSV-1-B_seqs.fasta
# done
# cluster_seqs/2JS1-1-A_seqs.fasta
# done
# cluster_seqs/2JS1-2-A_seqs.fasta
# done
# cluster_seqs/2JS1-4-A_seqs.fasta
# done
# cluster_seqs/2JS1-2-B_seqs.fasta
# done
# cluster_seqs/1MSF-20-A_seqs.fasta
# done
# cluster_seqs/1MSF-7-A_seqs.fasta
# done
# cluster_seqs/1MSF-3-C_seqs.fasta
# done
# cluster_seqs/1MSF-14-C_seqs.fasta
# done
# cluster_seqs/1GV2--1-A_seqs.fasta
# done
# cluster_seqs/1MSF-4-A_seqs.fasta
# done
# cluster_seqs/1MSF-6-C_seqs.fasta
# done
# cluster_seqs/1MSF-19-A_seqs.fasta
# done
# cluster_seqs/1MSF-4-C_seqs.fasta
# done
# cluster_seqs/1MSF-5-A_seqs.fasta
# done
# cluster_seqs/1MSF-5-C_seqs.fasta
# done
# cluster_seqs/1MSF--1-A_seqs.fasta
# done
# cluster_seqs/1MSF-7-C_seqs.fasta
# done
# cluster_seqs/1MSF-14-A_seqs.fasta
# done
# cluster_seqs/1MSF-20-C_seqs.fasta
# done
# cluster_seqs/1MSF-3-A_seqs.fasta
# done
# cluster_seqs/1MSF-6-A_seqs.fasta
# done
# cluster_seqs/1MSF--1-C_seqs.fasta
# done
# cluster_seqs/1MSF-19-C_seqs.fasta
# done
# cluster_seqs/1MSF-1-C_seqs.fasta
# done
# cluster_seqs/1MSF-1-A_seqs.fasta
# done
# cluster_seqs/1MSF-2-A_seqs.fasta
# done
# cluster_seqs/1MSF-2-C_seqs.fasta
# done
# cluster_seqs/2L7F-1-P_seqs.fasta
# done
# cluster_seqs/2KAN-6-A_seqs.fasta
# done
# cluster_seqs/2KAN-8-A_seqs.fasta
# done
# cluster_seqs/2KAN-3-A_seqs.fasta
# done
# cluster_seqs/2KAN-17-A_seqs.fasta
# done
# cluster_seqs/2KAN-15-A_seqs.fasta
# done
# cluster_seqs/2KAN-4-A_seqs.fasta
# done
# cluster_seqs/2KAN-13-A_seqs.fasta
# done
# cluster_seqs/2KAN-2-A_seqs.fasta
# done
# cluster_seqs/2N4F-4-A_seqs.fasta
# done
# cluster_seqs/2KAN-20-A_seqs.fasta
# done
# cluster_seqs/2N4F-2-A_seqs.fasta
# done
# cluster_seqs/2KAN-9-A_seqs.fasta
# done
# cluster_seqs/2N4F-10-A_seqs.fasta
# done
# cluster_seqs/2N4F-1-A_seqs.fasta
# done
# cluster_seqs/2KAN-10-A_seqs.fasta
# done
# cluster_seqs/2KAN-7-A_seqs.fasta
# done
# cluster_seqs/2KAN-5-A_seqs.fasta
# done
# cluster_seqs/2KAN-11-A_seqs.fasta
# done
# cluster_seqs/2KAN-12-A_seqs.fasta
# done
# cluster_seqs/2KAN-1-A_seqs.fasta
# done
# cluster_seqs/2N4F-11-A_seqs.fasta
# done
# cluster_seqs/2N4F-9-A_seqs.fasta
# done
# cluster_seqs/1Q7I-5-A_seqs.fasta
# done
# cluster_seqs/1Q7I-2-A_seqs.fasta
# done
# cluster_seqs/1Q7I-7-A_seqs.fasta
# done
# cluster_seqs/1Q7I-4-A_seqs.fasta
# done
# cluster_seqs/1Q7I-11-A_seqs.fasta
# done
# cluster_seqs/1Q7I-6-A_seqs.fasta
# done
# cluster_seqs/1Q7I-8-A_seqs.fasta
# done
# cluster_seqs/1Q7I-3-A_seqs.fasta
# done
# cluster_seqs/1Q7I-1-A_seqs.fasta
# done
# cluster_seqs/4L6V--1-E_seqs.fasta
# done
# cluster_seqs/6UZV--1-e_seqs.fasta
# done
# cluster_seqs/6UZV--1-E_seqs.fasta
# done
# cluster_seqs/6UZV--1-5_seqs.fasta
# done
# cluster_seqs/4TTM-1-B_seqs.fasta
# done
# cluster_seqs/2KHB-1-A_seqs.fasta
# done
# cluster_seqs/4TTM--1-B_seqs.fasta
# done
# cluster_seqs/4TTM--1-A_seqs.fasta
# done
# cluster_seqs/4TTM-1-A_seqs.fasta
# done
# cluster_seqs/1QP9-1-D_seqs.fasta
# done
# cluster_seqs/2HAP--1-A_seqs.fasta
# done
# cluster_seqs/1QP9-1-C_seqs.fasta
# done
# cluster_seqs/1QP9--1-C_seqs.fasta
# done
# cluster_seqs/2HAP--1-C_seqs.fasta
# done
# cluster_seqs/1HWT--1-C_seqs.fasta
# done
# cluster_seqs/1QP9--1-A_seqs.fasta
# done
# cluster_seqs/1QP9-1-G_seqs.fasta
# done
# cluster_seqs/1QP9--1-B_seqs.fasta
# done
# cluster_seqs/1QP9-1-B_seqs.fasta
# done
# cluster_seqs/1HWT--1-A_seqs.fasta
# done
# cluster_seqs/1HWT--1-G_seqs.fasta
# done
# cluster_seqs/1QP9-1-A_seqs.fasta
# done
# cluster_seqs/1QP9--1-G_seqs.fasta
# done
# cluster_seqs/1QP9--1-D_seqs.fasta
# done
# cluster_seqs/2HAP--1-D_seqs.fasta
# done
# cluster_seqs/1RK7-1-A_seqs.fasta
# done
# cluster_seqs/1RK7-20-A_seqs.fasta
# done
# cluster_seqs/1RK7-21-A_seqs.fasta
# done
# cluster_seqs/1RK7-3-A_seqs.fasta
# done
# cluster_seqs/1RK7-2-A_seqs.fasta
# done
# cluster_seqs/1KMG-23-A_seqs.fasta
# done
# cluster_seqs/1BA9-4-A_seqs.fasta
# done
# cluster_seqs/1RK7-23-A_seqs.fasta
# done
# cluster_seqs/1RK7-4-A_seqs.fasta
# done
# cluster_seqs/1RK7-5-A_seqs.fasta
# done
# cluster_seqs/1RK7-22-A_seqs.fasta
# done
# cluster_seqs/1RK7-7-A_seqs.fasta
# done
# cluster_seqs/1KMG-5-A_seqs.fasta
# done
# cluster_seqs/1BA9-22-A_seqs.fasta
# done
# cluster_seqs/7B3J-10-A_seqs.fasta
# done
# cluster_seqs/7B3J-4-A_seqs.fasta
# done
# cluster_seqs/7B3J-5-A_seqs.fasta
# done
# cluster_seqs/7B3J-2-A_seqs.fasta
# done
# cluster_seqs/7B3J-8-A_seqs.fasta
# done
# cluster_seqs/7B3J-6-A_seqs.fasta
# done
# cluster_seqs/7B3J-1-A_seqs.fasta
# done
# cluster_seqs/7B3J-3-A_seqs.fasta
# done
# cluster_seqs/2CRL-15-A_seqs.fasta
# done
# cluster_seqs/2CRL-5-A_seqs.fasta
# done
# cluster_seqs/2CRL-4-A_seqs.fasta
# done
# cluster_seqs/2CRL-2-A_seqs.fasta
# done
# cluster_seqs/2CRL-9-A_seqs.fasta
# done
# cluster_seqs/2CRL-17-A_seqs.fasta
# done
# cluster_seqs/2RSQ-3-A_seqs.fasta
# done
# cluster_seqs/2RSQ-5-A_seqs.fasta
# done
# cluster_seqs/2RSQ-4-A_seqs.fasta
# done
# cluster_seqs/2CRL-8-A_seqs.fasta
# done
# cluster_seqs/2CRL-10-A_seqs.fasta
# done
# cluster_seqs/2CRL-1-A_seqs.fasta
# done
# cluster_seqs/2CRL-20-A_seqs.fasta
# done
# cluster_seqs/2CRL-13-A_seqs.fasta
# done
# cluster_seqs/2CRL-3-A_seqs.fasta
# done
# cluster_seqs/2CRL-14-A_seqs.fasta
# done
# cluster_seqs/2RSQ-2-A_seqs.fasta
# done
# cluster_seqs/2RSQ-1-A_seqs.fasta
# done
# cluster_seqs/2CRL-7-A_seqs.fasta
# done
# cluster_seqs/2CRL-12-A_seqs.fasta
# done
# cluster_seqs/2CRL-19-A_seqs.fasta
# done
# cluster_seqs/2CRL-6-A_seqs.fasta
# done
# cluster_seqs/2CRL-11-A_seqs.fasta
# done
# cluster_seqs/2CRL-18-A_seqs.fasta
# done
# cluster_seqs/2CRL-16-A_seqs.fasta
# done
# cluster_seqs/1OLH-1-B_seqs.fasta
# done
# cluster_seqs/1OLH-2-B_seqs.fasta
# done
# cluster_seqs/1OLH-5-B_seqs.fasta
# done
# cluster_seqs/1OLH-5-D_seqs.fasta
# done
# cluster_seqs/1OLH-3-B_seqs.fasta
# done
# cluster_seqs/1OLH-2-A_seqs.fasta
# done
# cluster_seqs/1OLH-3-A_seqs.fasta
# done
# cluster_seqs/1OLH-24-A_seqs.fasta
# done
# cluster_seqs/1OLH-4-D_seqs.fasta
# done
# cluster_seqs/1OLH-1-A_seqs.fasta
# done
# cluster_seqs/1SAF-1-A_seqs.fasta
# done
# cluster_seqs/1OLH-1-D_seqs.fasta
# done
# cluster_seqs/1OLH-24-B_seqs.fasta
# done
# cluster_seqs/1OLH-5-A_seqs.fasta
# done
# cluster_seqs/1OLH-3-D_seqs.fasta
# done
# cluster_seqs/1OLH-4-B_seqs.fasta
# done
# cluster_seqs/1OLH-24-D_seqs.fasta
# done
# cluster_seqs/1OLH-2-D_seqs.fasta
# done
# cluster_seqs/1OLH-4-A_seqs.fasta
# done
# cluster_seqs/2AHM--1-D_seqs.fasta
# done
# cluster_seqs/6NUR-1-C_seqs.fasta
# done
# cluster_seqs/6NUR-1-D_seqs.fasta
# done
# cluster_seqs/2AHM--1-B_seqs.fasta
# done
# cluster_seqs/6NUR--1-C_seqs.fasta
# done
# cluster_seqs/2AHM-1-A_seqs.fasta
# done
# cluster_seqs/6NUR-1-B_seqs.fasta
# done
# cluster_seqs/2AHM-1-B_seqs.fasta
# done
# cluster_seqs/6NUR--1-D_seqs.fasta
# done
# cluster_seqs/2AHM-1-D_seqs.fasta
# done
# cluster_seqs/6NUR--1-B_seqs.fasta
# done
# cluster_seqs/2AHM--1-A_seqs.fasta
# done
# cluster_seqs/2AHM-1-C_seqs.fasta
# done
# cluster_seqs/2AHM--1-C_seqs.fasta
# done
# cluster_seqs/2KF2-4-A_seqs.fasta
# done
# cluster_seqs/2KF2-5-A_seqs.fasta
# done
# cluster_seqs/2KF2-2-A_seqs.fasta
# done
# cluster_seqs/2KF2-7-A_seqs.fasta
# done
# cluster_seqs/2KF2-1-A_seqs.fasta
# done
# cluster_seqs/2KF2-3-A_seqs.fasta
# done
# cluster_seqs/2KF2-6-A_seqs.fasta
# done
# cluster_seqs/2KF2--1-A_seqs.fasta
# done
# cluster_seqs/2KF2-9-A_seqs.fasta
# done
# cluster_seqs/2ENS-20-A_seqs.fasta
# done
# cluster_seqs/2ENS-11-A_seqs.fasta
# done
# cluster_seqs/2ENS-15-A_seqs.fasta
# done
# cluster_seqs/2ENS-5-A_seqs.fasta
# done
# cluster_seqs/2LE9--1-D_seqs.fasta
# done
# cluster_seqs/2ENS-16-A_seqs.fasta
# done
# cluster_seqs/2ENS-7-A_seqs.fasta
# done
# cluster_seqs/2LE9-1-D_seqs.fasta
# done
# cluster_seqs/2ENS-6-A_seqs.fasta
# done
# cluster_seqs/2ENS-1-A_seqs.fasta
# done
# cluster_seqs/2ENS--1-A_seqs.fasta
# done
# cluster_seqs/2ENS-3-A_seqs.fasta
# done
# cluster_seqs/2ENS-4-A_seqs.fasta
# done
# cluster_seqs/2LE9--1-A_seqs.fasta
# done
# cluster_seqs/2LE9-1-A_seqs.fasta
# done
# cluster_seqs/2ENS-2-A_seqs.fasta
# done
# cluster_seqs/2ENS-13-A_seqs.fasta
# done
# cluster_seqs/2ENS-12-A_seqs.fasta
# done
# cluster_seqs/2ENS-19-A_seqs.fasta
# done
# cluster_seqs/6NEZ--1-A_seqs.fasta
# done
# cluster_seqs/6NEZ--1-D_seqs.fasta
# done
# cluster_seqs/6NEZ--1-C_seqs.fasta
# done
# cluster_seqs/6NEZ--1-B_seqs.fasta
# done
# cluster_seqs/1MYL--1-B_seqs.fasta
# done
# cluster_seqs/1B28-4-A_seqs.fasta
# done
# cluster_seqs/1B28-3-A_seqs.fasta
# done
# cluster_seqs/1MYL-1-A_seqs.fasta
# done
# cluster_seqs/1B28-1-A_seqs.fasta
# done
# cluster_seqs/1MYL--1-D_seqs.fasta
# done
# cluster_seqs/1MYL--1-E_seqs.fasta
# done
# cluster_seqs/1B28-7-A_seqs.fasta
# done
# cluster_seqs/1MYL-1-B_seqs.fasta
# done
# cluster_seqs/1B28-5-A_seqs.fasta
# done
# cluster_seqs/1MYL-1-C_seqs.fasta
# done
# cluster_seqs/1MYL--1-C_seqs.fasta
# done
# cluster_seqs/1B28-10-A_seqs.fasta
# done
# cluster_seqs/1MYL--1-A_seqs.fasta
# done
# cluster_seqs/1B28-8-A_seqs.fasta
# done
# cluster_seqs/1B28-6-A_seqs.fasta
# done
# cluster_seqs/1B28-12-A_seqs.fasta
# done
# cluster_seqs/1MYL-1-E_seqs.fasta
# done
# cluster_seqs/1B28-2-A_seqs.fasta
# done
# cluster_seqs/1B28--1-A_seqs.fasta
# done
# cluster_seqs/1MYL-1-D_seqs.fasta
# done
# cluster_seqs/6Y95-4-A_seqs.fasta
# done
# cluster_seqs/6Y94--1-A_seqs.fasta
# done
# cluster_seqs/6Y4P--1-A_seqs.fasta
# done
# cluster_seqs/6Y95--1-A_seqs.fasta
# done
# cluster_seqs/6Y4P--1-B_seqs.fasta
# done
# cluster_seqs/6Y94-1-A_seqs.fasta
# done
# cluster_seqs/6Y4P-1-B_seqs.fasta
# done
# cluster_seqs/6Y4P-1-A_seqs.fasta
# done
# cluster_seqs/4GLN--1-D_seqs.fasta
# done
# cluster_seqs/4GLN--1-H_seqs.fasta
# done
# cluster_seqs/4GLS--1-D_seqs.fasta
# done
# cluster_seqs/4GLS--1-H_seqs.fasta
# done
# cluster_seqs/2N47-6-A_seqs.fasta
# done
# cluster_seqs/2N47--1-A_seqs.fasta
# done
# cluster_seqs/2N47-14-A_seqs.fasta
# done
# cluster_seqs/2N47-10-A_seqs.fasta
# done
# cluster_seqs/2N47-1-A_seqs.fasta
# done
# cluster_seqs/2N47-18-A_seqs.fasta
# done
# cluster_seqs/2N47-16-A_seqs.fasta
# done
# cluster_seqs/3UCW--1-B_seqs.fasta
# done
# cluster_seqs/3UCW--1-A_seqs.fasta
# done
# cluster_seqs/2LQC--1-A_seqs.fasta
# done
# cluster_seqs/2LQC-10-A_seqs.fasta
# done
# cluster_seqs/2LLO-4-A_seqs.fasta
# done
# cluster_seqs/2LQC-4-A_seqs.fasta
# done
# cluster_seqs/3UCW-1-A_seqs.fasta
# done
# cluster_seqs/2LQC-6-A_seqs.fasta
# done
# cluster_seqs/2LLO--1-A_seqs.fasta
# done
# cluster_seqs/3UCW-1-D_seqs.fasta
# done
# cluster_seqs/3UCW--1-C_seqs.fasta
# done
# cluster_seqs/2LLO-2-A_seqs.fasta
# done
# cluster_seqs/3UCW-1-B_seqs.fasta
# done
# cluster_seqs/2LQC-1-A_seqs.fasta
# done
# cluster_seqs/2LLO-3-A_seqs.fasta
# done
# cluster_seqs/3UCT--1-A_seqs.fasta
# done
# cluster_seqs/3UCW--1-D_seqs.fasta
# done
# cluster_seqs/2LLO-1-A_seqs.fasta
# done
# cluster_seqs/3UCW-1-C_seqs.fasta
# done
# cluster_seqs/1KLD-3-A_seqs.fasta
# done
# cluster_seqs/1KLA-1-A_seqs.fasta
# done
# cluster_seqs/4KV5--1-A_seqs.fasta
# done
# cluster_seqs/6GFF--1-B_seqs.fasta
# done
# cluster_seqs/1KLA--1-A_seqs.fasta
# done
# cluster_seqs/3KFD-1-B_seqs.fasta
# done
# cluster_seqs/3KFD-1-A_seqs.fasta
# done
# cluster_seqs/1KLC--1-B_seqs.fasta
# done
# cluster_seqs/3KFD--1-A_seqs.fasta
# done
# cluster_seqs/6GFF--1-D_seqs.fasta
# done
# cluster_seqs/1KLD-1-A_seqs.fasta
# done
# cluster_seqs/3KFD--1-C_seqs.fasta
# done
# cluster_seqs/3KFD--1-D_seqs.fasta
# done
# cluster_seqs/1KLD-2-A_seqs.fasta
# done
# cluster_seqs/3KFD-1-D_seqs.fasta
# done
# cluster_seqs/1KLC--1-A_seqs.fasta
# done
# cluster_seqs/6GFF--1-A_seqs.fasta
# done
# cluster_seqs/1KLD-4-A_seqs.fasta
# done
# cluster_seqs/1KLD--1-A_seqs.fasta
# done
# cluster_seqs/4KV5--1-C_seqs.fasta
# done
# cluster_seqs/3KFD--1-B_seqs.fasta
# done
# cluster_seqs/3KFD-1-C_seqs.fasta
# done
# cluster_seqs/4KV5--1-D_seqs.fasta
# done
# cluster_seqs/2LSA-3-A_seqs.fasta
# done
# cluster_seqs/2LSA-7-A_seqs.fasta
# done
# cluster_seqs/2LSA-10-A_seqs.fasta
# done
# cluster_seqs/2LSA-2-A_seqs.fasta
# done
# cluster_seqs/2MAG-2-A_seqs.fasta
# done
# cluster_seqs/2LSA-5-A_seqs.fasta
# done
# cluster_seqs/2LSA-1-A_seqs.fasta
# done
# cluster_seqs/2MAG-6-A_seqs.fasta
# done
# cluster_seqs/2MAG-10-A_seqs.fasta
# done
# cluster_seqs/2MAG-1-A_seqs.fasta
# done
# cluster_seqs/2LSA-4-A_seqs.fasta
# done
# cluster_seqs/2LSA-6-A_seqs.fasta
# done
# cluster_seqs/2MAG-3-A_seqs.fasta
# done
# cluster_seqs/5LW4-6-A_seqs.fasta
# done
# cluster_seqs/5LW4-5-A_seqs.fasta
# done
# cluster_seqs/6TWE-1-A_seqs.fasta
# done
# cluster_seqs/5LW4-20-A_seqs.fasta
# done
# cluster_seqs/5LW4-3-A_seqs.fasta
# done
# cluster_seqs/5LW4-4-A_seqs.fasta
# done
# cluster_seqs/5LW4-1-A_seqs.fasta
# done
# cluster_seqs/6TWE-6-A_seqs.fasta
# done
# cluster_seqs/5LW4-2-A_seqs.fasta
# done
# cluster_seqs/2L0N-7-A_seqs.fasta
# done
# cluster_seqs/2L0N-6-A_seqs.fasta
# done
# cluster_seqs/2L0N-4-A_seqs.fasta
# done
# cluster_seqs/2L0N-9-A_seqs.fasta
# done
# cluster_seqs/2L0O-4-A_seqs.fasta
# done
# cluster_seqs/2L0O-1-A_seqs.fasta
# done
# cluster_seqs/2L0N-1-A_seqs.fasta
# done
# cluster_seqs/2L0N-3-A_seqs.fasta
# done
# cluster_seqs/2L0N-5-A_seqs.fasta
# done
# cluster_seqs/2L0N-16-A_seqs.fasta
# done
# cluster_seqs/2L0O-3-A_seqs.fasta
# done
# cluster_seqs/2L0O-6-A_seqs.fasta
# done
# cluster_seqs/2L0N-8-A_seqs.fasta
# done
# cluster_seqs/2L0N-2-A_seqs.fasta
# done
# cluster_seqs/1CWW-19-A_seqs.fasta
# done
# cluster_seqs/1CWW-4-A_seqs.fasta
# done
# cluster_seqs/1C15-1-A_seqs.fasta
# done
# cluster_seqs/1CWW-7-A_seqs.fasta
# done
# cluster_seqs/1CWW-3-A_seqs.fasta
# done
# cluster_seqs/1C15-4-A_seqs.fasta
# done
# cluster_seqs/1C15-2-A_seqs.fasta
# done
# cluster_seqs/1CWW-5-A_seqs.fasta
# done
# cluster_seqs/1C15-3-A_seqs.fasta
# done
# cluster_seqs/1CWW-6-A_seqs.fasta
# done
# cluster_seqs/1CWW-10-A_seqs.fasta
# done
# cluster_seqs/1CWW-16-A_seqs.fasta
# done
# cluster_seqs/1CWW-1-A_seqs.fasta
# done
# cluster_seqs/1CWW-2-A_seqs.fasta
# done
# cluster_seqs/1CWW-12-A_seqs.fasta
# done
# cluster_seqs/1D9N-2-A_seqs.fasta
# done
# cluster_seqs/1D9N-8-A_seqs.fasta
# done
# cluster_seqs/1D9N-6-A_seqs.fasta
# done
# cluster_seqs/1D9N-4-A_seqs.fasta
# done
# cluster_seqs/1IG4-3-A_seqs.fasta
# done
# cluster_seqs/1D9N-7-A_seqs.fasta
# done
# cluster_seqs/1D9N-19-A_seqs.fasta
# done
# cluster_seqs/1IG4-1-A_seqs.fasta
# done
# cluster_seqs/1D9N-3-A_seqs.fasta
# done
# cluster_seqs/1IG4-4-A_seqs.fasta
# done
# cluster_seqs/1D9N-5-A_seqs.fasta
# done
# cluster_seqs/1D9N-17-A_seqs.fasta
# done
# cluster_seqs/1IG4-8-A_seqs.fasta
# done
# cluster_seqs/1IG4-7-A_seqs.fasta
# done
# cluster_seqs/1D9N-1-A_seqs.fasta
# done
# cluster_seqs/1KBH-14-B_seqs.fasta
# done
# cluster_seqs/2C52-11-A_seqs.fasta
# done
# cluster_seqs/2C52-18-A_seqs.fasta
# done
# cluster_seqs/2C52-2-A_seqs.fasta
# done
# cluster_seqs/1KBH-1-A_seqs.fasta
# done
# cluster_seqs/1KBH-14-A_seqs.fasta
# done
# cluster_seqs/1KBH-1-B_seqs.fasta
# done
# cluster_seqs/2KKJ-1-A_seqs.fasta
# done
# cluster_seqs/2C52-14-A_seqs.fasta
# done
# cluster_seqs/2KMV-15-A_seqs.fasta
# done
# cluster_seqs/2KND-7-A_seqs.fasta
# done
# cluster_seqs/2KND-18-A_seqs.fasta
# done
# cluster_seqs/2KMV-6-A_seqs.fasta
# done
# cluster_seqs/2KND-5-A_seqs.fasta
# done
# cluster_seqs/2KMV-7-A_seqs.fasta
# done
# cluster_seqs/2KND-20-A_seqs.fasta
# done
# cluster_seqs/2KMV-14-A_seqs.fasta
# done
# cluster_seqs/2KMF-1-A_seqs.fasta
# done
# cluster_seqs/2KMV-20-A_seqs.fasta
# done
# cluster_seqs/2KMF-5-A_seqs.fasta
# done
# cluster_seqs/2KND-6-A_seqs.fasta
# done
# cluster_seqs/2KMV-11-A_seqs.fasta
# done
# cluster_seqs/2KMF-2-A_seqs.fasta
# done
# cluster_seqs/2KND-3-A_seqs.fasta
# done
# cluster_seqs/2KMV-19-A_seqs.fasta
# done
# cluster_seqs/2KND-13-A_seqs.fasta
# done
# cluster_seqs/2KND-4-A_seqs.fasta
# done
# cluster_seqs/2KMF-7-A_seqs.fasta
# done
# cluster_seqs/2KMV-12-A_seqs.fasta
# done
# cluster_seqs/2KMF-18-A_seqs.fasta
# done
# cluster_seqs/2KMV-4-A_seqs.fasta
# done
# cluster_seqs/2KMF-6-A_seqs.fasta
# done
# cluster_seqs/2KMV-18-A_seqs.fasta
# done
# cluster_seqs/2KMF-20-A_seqs.fasta
# done
# cluster_seqs/2KND-2-A_seqs.fasta
# done
# cluster_seqs/2KND-1-A_seqs.fasta
# done
# cluster_seqs/2KMV-8-A_seqs.fasta
# done
# cluster_seqs/2KMV-5-A_seqs.fasta
# done
# cluster_seqs/2KMF-13-A_seqs.fasta
# done
# cluster_seqs/2KMV-16-A_seqs.fasta
# done
# cluster_seqs/5FRF-3-A_seqs.fasta
# done
# cluster_seqs/5FRF-4-A_seqs.fasta
# done
# cluster_seqs/5FRH-2-A_seqs.fasta
# done
# cluster_seqs/5FRF-10-A_seqs.fasta
# done
# cluster_seqs/5FRF-6-A_seqs.fasta
# done
# cluster_seqs/5FRF-2-A_seqs.fasta
# done
# cluster_seqs/5FRF-1-A_seqs.fasta
# done
# cluster_seqs/5FRH-3-A_seqs.fasta
# done
# cluster_seqs/5FRH-1-A_seqs.fasta
# done
# cluster_seqs/5FRF-7-A_seqs.fasta
# done
# cluster_seqs/5FRF-5-A_seqs.fasta
# done
# cluster_seqs/5FRH-4-A_seqs.fasta
# done
# cluster_seqs/2KPW-1-A_seqs.fasta
# done
# cluster_seqs/2LJY-18-A_seqs.fasta
# done
# cluster_seqs/2LJY-2-A_seqs.fasta
# done
# cluster_seqs/2LJY-5-B_seqs.fasta
# done
# cluster_seqs/2LJY-5-A_seqs.fasta
# done
# cluster_seqs/2LJY-18-B_seqs.fasta
# done
# cluster_seqs/2LJY-12-B_seqs.fasta
# done
# cluster_seqs/2LJX-1-A_seqs.fasta
# done
# cluster_seqs/2LJY-12-A_seqs.fasta
# done
# cluster_seqs/2LJY-1-A_seqs.fasta
# done
# cluster_seqs/2LJY-11-B_seqs.fasta
# done
# cluster_seqs/2LJY-2-B_seqs.fasta
# done
# cluster_seqs/2LJY-11-A_seqs.fasta
# done
# cluster_seqs/2LJY-1-B_seqs.fasta
# done

# %%
from tqdm import tqdm

# %%
with open("full_data.csv", "w") as full_data:
    print("pdb_index,cluster_id,pdb_cluster_id,file_name,pdb,chain,model,causes", file=full_data)
    i = 0
    for cluster_seqs in tqdm(list(Path("cluster_seqs/full").glob("*.fasta"))):
        cluster_name = cluster_seqs.stem
        with cluster_seqs.open() as fasta:
            for j, line in enumerate(fasta):
                fields = line[1:].rstrip().split()
                pdb, chain = fields[0].split("_")
                if len(fields) > 1:
                    model = int(fields[1])
                else:
                    model = None
                seq = next(fasta)

                df = pd.read_csv(f"codnas_raw_data/{cluster_name[:6]}.csv", index_col=0)
    
                if "Mammoth_RMS" not in df.columns:
                    continue
                    
                df = df[pd.to_numeric(df['Mammoth_RMS'], errors='coerce').notnull()]
            
                df["Mammoth_RMS"] = df["Mammoth_RMS"].astype(float)
                
                if len(df[df.Mammoth_RMS>4])==0:
                    continue
            
                try:
                    df = df.groupby(pd.cut(df["Mammoth_RMS"], np.arange(0, df["Mammoth_RMS"].max(), df["Mammoth_RMS"].quantile(0.2)))).head(4)
                except ValueError:
                    continue
                
            
                try:
                    df = df.assign(
                        pdb1=df["PDB_1"].str[:4],
                        pdb2=df["PDB_2"].str[:4],
                        model1=df["PDB_1"].astype(str).apply(lambda s: s.split("-")[1].split("_")[0] if "-" in s else -1).astype(int),
                        model2=df["PDB_2"].astype(str).apply(lambda s: s.split("-")[1].split("_")[0] if "-" in s else -1).astype(int),
                        chain1=df["PDB_1"].str.split("_", expand=True)[1],
                        chain2=df["PDB_2"].str.split("_", expand=True)[1],
                    )
                except (TypeError, KeyError):
                    continue
    
                if model is None:
                    small_df = df[((df["pdb1"]==pdb)&(df["chain1"]==chain))|((df["pdb2"]==pdb)&(df["chain2"]==chain))]
                else:
                    small_df = df[((df["pdb1"]==pdb)&(df["chain1"]==chain)&(df["model1"]==model))|((df["pdb2"]==pdb)&(df["chain2"]==chain)&(df["model2"]==model))]

                causes = ";".join(set(small_df["Causes_DC"].str.split(",", expand=True).dropna().values.flatten()))

                if model is None:
                    file_name = f"codnas_groups_pdb/{cluster_name}/{pdb}--1-{chain}_fixed.pdb"
                else:
                    file_name = f"codnas_groups_pdb/{cluster_name}/{pdb}-{model}-{chain}_fixed.pdb"
                print(i, cluster_name, f"{cluster_name}_{j}", file_name, pdb, chain, model, causes, sep=", ", file=full_data)

                i += 1
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1428/1428 [26:36<00:00,  1.12s/it]

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
all_data_df = pd.read_csv("full_data.csv", sep=", ")
# Out:
# /tmp/ipykernel_3347114/3658753745.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   all_data_df = pd.read_csv("full_data.csv", sep=", ")

# %%
all_data_df
# Out:
#        pdb_index   cluster_id pdb_cluster_id  \
# 0              0  4JNE_A_seqs  4JNE_A_seqs_0
# 1              1  4JNE_A_seqs  4JNE_A_seqs_1
# 2              2  4JNE_A_seqs  4JNE_A_seqs_2
# 3              3  4JNE_A_seqs  4JNE_A_seqs_3
# 4              4  4JNE_A_seqs  4JNE_A_seqs_4
# ...          ...          ...            ...
# 19197      19197  1AP0_A_seqs  1AP0_A_seqs_4
# 19198      19198  1AP0_A_seqs  1AP0_A_seqs_5
# 19199      19199  1AP0_A_seqs  1AP0_A_seqs_6
# 19200      19200  1AP0_A_seqs  1AP0_A_seqs_7
# 19201      19201  1AP0_A_seqs  1AP0_A_seqs_8
#
#                                                file_name   pdb chain model  \
# 0       codnas_groups_pdb/4JNE_A_seqs/2VB5-6-A_fixed.pdb  2VB5     A     6
# 1      codnas_groups_pdb/4JNE_A_seqs/2VB5-17-A_fixed.pdb  2VB5     A    17
# 2      codnas_groups_pdb/4JNE_A_seqs/2VB5-20-A_fixed.pdb  2VB5     A    20
# 3      codnas_groups_pdb/4JNE_A_seqs/2VB5-15-A_fixed.pdb  2VB5     A    15
# 4      codnas_groups_pdb/4JNE_A_seqs/2KF2-11-A_fixed.pdb  2KF2     A    11
# ...                                                  ...   ...   ...   ...
# 19197   codnas_groups_pdb/1AP0_A_seqs/1AP0-6-A_fixed.pdb  1AP0     A     6
# 19198   codnas_groups_pdb/1AP0_A_seqs/1AP0-3-A_fixed.pdb  1AP0     A     3
# 19199   codnas_groups_pdb/1AP0_A_seqs/1AP0-1-A_fixed.pdb  1AP0     A     1
# 19200  codnas_groups_pdb/1AP0_A_seqs/1AP0-16-A_fixed.pdb  1AP0     A    16
# 19201  codnas_groups_pdb/1AP0_A_seqs/1AP0-13-A_fixed.pdb  1AP0     A    13
#
#                                              causes
# 0                                          MUTATION
# 1                                          MUTATION
# 2                                          MUTATION
# 3                                          MUTATION
# 4      LIGAND;TEMPERATURE;LIGAND BIOLIP;PH;MUTATION
# ...                                             ...
# 19197                                      MUTATION
# 19198                                      MUTATION
# 19199                                      MUTATION
# 19200                                      MUTATION
# 19201                                      MUTATION
#
# [19202 rows x 8 columns]

# %%
all_data_df = all_data_df.assign(**{f"embedding{x}":np.nan for x in range(1280)})
all_data_df.head()
# Out:
#    pdb_index   cluster_id pdb_cluster_id  \
# 0          0  4JNE_A_seqs  4JNE_A_seqs_0
# 1          1  4JNE_A_seqs  4JNE_A_seqs_1
# 2          2  4JNE_A_seqs  4JNE_A_seqs_2
# 3          3  4JNE_A_seqs  4JNE_A_seqs_3
# 4          4  4JNE_A_seqs  4JNE_A_seqs_4
#
#                                            file_name   pdb chain model  \
# 0   codnas_groups_pdb/4JNE_A_seqs/2VB5-6-A_fixed.pdb  2VB5     A     6
# 1  codnas_groups_pdb/4JNE_A_seqs/2VB5-17-A_fixed.pdb  2VB5     A    17
# 2  codnas_groups_pdb/4JNE_A_seqs/2VB5-20-A_fixed.pdb  2VB5     A    20
# 3  codnas_groups_pdb/4JNE_A_seqs/2VB5-15-A_fixed.pdb  2VB5     A    15
# 4  codnas_groups_pdb/4JNE_A_seqs/2KF2-11-A_fixed.pdb  2KF2     A    11
#
#                                          causes  embedding0  embedding1  ...  \
# 0                                      MUTATION         NaN         NaN  ...
# 1                                      MUTATION         NaN         NaN  ...
# 2                                      MUTATION         NaN         NaN  ...
# 3                                      MUTATION         NaN         NaN  ...
# 4  LIGAND;TEMPERATURE;LIGAND BIOLIP;PH;MUTATION         NaN         NaN  ...
#
#    embedding1270  embedding1271  embedding1272  embedding1273  embedding1274  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    embedding1275  embedding1276  embedding1277  embedding1278  embedding1279
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
# [5 rows x 1288 columns]

# %%
all_data_df["model"] = all_data_df["model"].fillna("None,")

# %%
all_data_df["model"] = all_data_df["model"].apply(lambda s: s[:-1] if s.endswith(",") else s).apply(lambda s: "nan" if s=="None" else s)

# %%
from tqdm import tqdm
for emb_file in tqdm(Path.cwd().glob("*.pt")):
    emb = torch.load(str(emb_file))["mean_representations"][33]
    print(emb)
    np.save(str(emb_file.with_suffix(".npy")), emb.numpy())
# Out:
# /home/bournelab/miniconda_qbi/envs/ConfDiff/bin/python

# %%
emb_cols = [f"embedding{x}" for x in range(1280)]

# %%
all_embs = []
for emb_file in tqdm(list(Path("embeddings/New_ESM1_Embeddings").glob("*.npy"))):
    #7L55_A_3_19200.npy
    #7JQC_F__19061.npy
    fields = emb_file.stem.split("_")
    pdb = fields[0]
    chain = fields[1]
    model = fields[2] if fields[2] != "" else "nan"
    emb = np.load(str(emb_file))
    all_embs.append([pdb,chain,model,*emb.tolist()])
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5407/5407 [00:00<00:00, 8527.72it/s]

# %%
all_embs = pd.DataFrame(all_embs, columns=["pdb", "chain", "model", *emb_cols])

# %%
all_embs.to_csv("all_embeddings.csv")

# %%
cluster_reps_emb_df = pd.merge(all_data_df.drop(columns=emb_cols), all_embs, on=["pdb", "chain", "model"])

# %%
cluster_reps_emb_df.drop_duplicates(subset=["cluser_id"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3347114/4194525317.py in ?()
# ----> 1 cluster_reps_emb_df.drop_duplicates(subset=["cluser_id"])
#
# ~/miniconda_qbi/envs/ConfDiff/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, subset, keep, inplace, ignore_index)
#    6562
#    6563         inplace = validate_bool_kwarg(inplace, "inplace")
#    6564         ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
#    6565
# -> 6566         result = self[-self.duplicated(subset, keep=keep)]
#    6567         if ignore_index:
#    6568             result.index = default_index(len(result))
#    6569
#
# ~/miniconda_qbi/envs/ConfDiff/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, subset, keep)
#    6694         # Otherwise, raise a KeyError, same as if you try to __getitem__ with a
#    6695         # key that doesn't exist.
#    6696         diff = set(subset) - set(self.columns)
#    6697         if diff:
# -> 6698             raise KeyError(Index(diff))
#    6699
#    6700         if len(subset) == 1 and self.columns.is_unique:
#    6701             # GH#45236 This is faster than get_group_index below
#
# KeyError: Index(['cluser_id'], dtype='object')

# %%
cluster_reps_emb_df
# Out:
#       pdb_index   cluster_id  pdb_cluster_id  \
# 0             7  1Y7J_A_seqs   1Y7J_A_seqs_0
# 1             8  1Y7J_A_seqs   1Y7J_A_seqs_1
# 2             9  1Y7J_A_seqs   1Y7J_A_seqs_2
# 3            10  1Y7J_A_seqs   1Y7J_A_seqs_3
# 4            11  1Y7J_A_seqs   1Y7J_A_seqs_4
# ...         ...          ...             ...
# 5552      19053  6P9Y_P_seqs   6P9Y_P_seqs_2
# 5553      19056  6P9Y_P_seqs   6P9Y_P_seqs_5
# 5554      19066  1AN1_I_seqs   1AN1_I_seqs_0
# 5555      19117  1L4W_A_seqs  1L4W_A_seqs_12
# 5556      19149  1L4W_A_seqs  1L4W_A_seqs_44
#
#                                               file_name   pdb chain model  \
# 0      codnas_groups_pdb/1Y7J_A_seqs/2KZA-2-A_fixed.pdb  2KZA     A     2
# 1     codnas_groups_pdb/1Y7J_A_seqs/2KZA-11-A_fixed.pdb  2KZA     A    11
# ...             ...            ...
# 5552      -0.096862       0.215431
# 5553      -0.112675       0.278666
# 5554      -0.135823       0.125113
# 5555      -0.064474       0.253057
# 5556      -0.064474       0.253057
#
# [5557 rows x 1288 columns]

# %%
pd.merge(
    all_data_df.drop(columns=emb_cols), 
    cluster_reps_emb_df.drop(columns=["pdb_index", "pdb_cluster_id", "file_name", "pdb", "chain", "model"]),
    how="inner",
    on="cluster_id")
# Out:
#         pdb_index   cluster_id  pdb_cluster_id  \
# 0               7  1Y7J_A_seqs   1Y7J_A_seqs_0
# 1               7  1Y7J_A_seqs   1Y7J_A_seqs_0
# 2               7  1Y7J_A_seqs   1Y7J_A_seqs_0
# 3               7  1Y7J_A_seqs   1Y7J_A_seqs_0
# 4               7  1Y7J_A_seqs   1Y7J_A_seqs_0
# ...           ...          ...             ...
# 130221      19190  1L4W_A_seqs  1L4W_A_seqs_85
# 130222      19191  1L4W_A_seqs  1L4W_A_seqs_86
# 130223      19191  1L4W_A_seqs  1L4W_A_seqs_86
# 130224      19192  1L4W_A_seqs  1L4W_A_seqs_87
# 130225      19192  1L4W_A_seqs  1L4W_A_seqs_87
#
#                                                 file_name   pdb chain model  \
# 0        codnas_groups_pdb/1Y7J_A_seqs/2KZA-2-A_fixed.pdb  2KZA     A     2
# 1        codnas_groups_pdb/1Y7J_A_seqs/2KZA-2-A_fixed.pdb  2KZA     A     2
# 2        codnas_groups_pdb/1Y7J_A_seqs/2KZA-2-A_fixed.pdb  2KZA     A     2
# 3        codnas_groups_pdb/1Y7J_A_seqs/2KZA-2-A_fixed.pdb  2KZA     A     2
# 4        codnas_groups_pdb/1Y7J_A_seqs/2KZA-2-A_fixed.pdb  2KZA     A     2
# ...                                                   ...   ...   ...   ...
# 130221   codnas_groups_pdb/1L4W_A_seqs/1IDL-1-A_fixed.pdb  1IDL     A     1
# 130222   codnas_groups_pdb/1L4W_A_seqs/1IKC-1-A_fixed.pdb  1IKC     A     1
# 130223   codnas_groups_pdb/1L4W_A_seqs/1IKC-1-A_fixed.pdb  1IKC     A     1
# 130224  codnas_groups_pdb/1L4W_A_seqs/1HC9--1-A_fixed.pdb  1HC9     A   nan
# 130225  codnas_groups_pdb/1L4W_A_seqs/1HC9--1-A_fixed.pdb  1HC9     A   nan
#
#                                 causes_x                          causes_y  \
# 0       TEMPERATURE;PH;DISORDER;MUTATION  TEMPERATURE;PH;DISORDER;MUTATION
# 1       TEMPERATURE;PH;DISORDER;MUTATION  TEMPERATURE;PH;DISORDER;MUTATION
# 2       TEMPERATURE;PH;DISORDER;MUTATION  TEMPERATURE;PH;DISORDER;MUTATION
# 3       TEMPERATURE;PH;DISORDER;MUTATION  TEMPERATURE;PH;DISORDER;MUTATION
# 4       TEMPERATURE;PH;DISORDER;MUTATION  TEMPERATURE;PH;DISORDER;MUTATION
# ...                                  ...                               ...
# 130221                              None                              None
# 130222                    TEMPERATURE;PH                              None
# 130223                    TEMPERATURE;PH                              None
# 130224                              None                              None
# 130225                              None                              None
#
#         embedding0  ...  embedding1270  embedding1271  embedding1272  \
# 0        -0.143577  ...       0.129885       0.049554       0.182815
# 1        -0.143577  ...       0.129885       0.049554       0.182815
# 2        -0.143577  ...       0.129885       0.049554       0.182815
# 3        -0.143577  ...       0.129885       0.049554       0.182815
# 4        -0.143577  ...       0.129885       0.049554       0.182815
# ...            ...  ...            ...            ...            ...
# 130221   -0.186269  ...      -0.128212       0.101672       0.013218
# 130222   -0.186269  ...      -0.128212       0.101672       0.013218
# 130223   -0.186269  ...      -0.128212       0.101672       0.013218
# 130224   -0.186269  ...      -0.128212       0.101672       0.013218
# 130225   -0.186269  ...      -0.128212       0.101672       0.013218
#
#         embedding1273  embedding1274  embedding1275  embedding1276  \
# 0           -0.127217      -0.249767      -0.023298       0.016290
# 1           -0.127217      -0.249767      -0.023298       0.016290
# 2           -0.127217      -0.249767      -0.023298       0.016290
# 3           -0.127217      -0.249767      -0.023298       0.016290
# 4           -0.127217      -0.249767      -0.023298       0.016290
# ...               ...            ...            ...            ...
# 130221       0.046467      -0.113594       0.041483      -0.203715
# 130222       0.046467      -0.113594       0.041483      -0.203715
# 130223       0.046467      -0.113594       0.041483      -0.203715
# 130224       0.046467      -0.113594       0.041483      -0.203715
# 130225       0.046467      -0.113594       0.041483      -0.203715
#
#         embedding1277  embedding1278  embedding1279
# 0            0.038949       0.096279       0.228959
# 1            0.038949       0.096279       0.228959
# 2            0.038949       0.096279       0.228959
# 3            0.038949       0.096279       0.228959
# 4            0.038949       0.096279       0.228959
# ...               ...            ...            ...
# 130221      -0.088847      -0.064474       0.253057
# 130222      -0.088847      -0.064474       0.253057
# 130223      -0.088847      -0.064474       0.253057
# 130224      -0.088847      -0.064474       0.253057
# 130225      -0.088847      -0.064474       0.253057
#
# [130226 rows x 1289 columns]

# %%
all_data_df.drop(columns=emb_cols).to_csv("all_input_data.csv")

# %%
"7JQC_F__19061".split("_")
# Out:
# ['7JQC', 'F', '', '19061']

# %%
trainValClusters = pd.read_csv("trainValClusters_cluster.tsv", sep="\t", header=None, names=["group", "pdb"])

# %%
for name, grp in df.groupby("group"):
    print(name, grp.shape)
# Out:
# 1A1X_A__3502 (14, 2)
# 1A5E_A_2_5446 (11, 2)
# 1A5R_A_1_32 (42, 2)
# 1A66_A_5_70 (9, 2)
# 1A6X_A_6_101 (17, 2)
# 1A8V_B__54 (11, 2)
# 1ACZ_C_3_145 (9, 2)
# 1AFO_A_2_8565 (30, 2)
# 1AHD_A_2_193 (7, 2)
# 1AJW_A__1568 (11, 2)
# 1AK7_A_7_208 (15, 2)
# 1AN1_I_1_219 (1, 2)
# 1AP7_A_1_482 (1, 2)
# 1AQT_A__18867 (4, 2)
# 1AX3_A_4_240 (9, 2)
# 1B4G_A_3_5359 (15, 2)
# 1B7F_B__14913 (46, 2)
# 1B8Q_B_7_3350 (9, 2)
# 1B9Q_A_8_295 (9, 2)
# 1BAL_A_4_4428 (26, 2)
# 1BET_A__16882 (10, 2)
# 1BHB_A_1_410 (15, 2)
# 2H80_A_9_6541 (13, 2)
# 2H8U_A__4394 (11, 2)
# 2H9E_C_1_6563 (1, 2)
# 2H9Z_A_8_6564 (9, 2)
# 2HAP_C__3487 (12, 2)
# 2HD7_A_1_19018 (1, 2)
# 2HDZ_A__6588 (12, 2)
# 2HI7_A__6681 (6, 2)
# 2HM6_A_10_6688 (22, 2)
# 2HNB_A_13_6710 (10, 2)
# 2HP8_A_5_6720 (11, 2)
# 2HSP_A_1_1796 (38, 2)
# 2HTS_A_1_6748 (10, 2)
# 2HUG_A_6_4674 (24, 2)
# 2HVA_A_5_6759 (19, 2)
# 2HVF_A__6575 (9, 2)
# 2I2Y_A_6_6778 (30, 2)
# 2I59_A_1_6787 (9, 2)
# 2I7U_B_3_6796 (12, 2)
# 2IDO_B_1_3727 (9, 2)
# 2IFB_A__1890 (25, 2)
# 2IIM_A__1696 (45, 2)
# 2IJK_B_1_6845 (26, 2)
# 2ITJ_A__6874 (10, 2)
# 2IZ4_A_10_4775 (21, 2)
# 2J4M_A_1_6928 (10, 2)
# 2J8J_B_1_6938 (16, 2)
# 2JDQ_E_1_6955 (2, 2)
# 2JHB_A_5_6960 (17, 2)
# 2JM1_A_20_6974 (17, 2)
# 2JMV_A_15_12658 (15, 2)
# 2JMW_A_15_7009 (13, 2)
# 2JMZ_A_3_7022 (8, 2)
# 2JN8_A_2_6157 (11, 2)
# 2JND_B_4_7030 (15, 2)
# 2JNS_A_2_12486 (25, 2)
# 2JOK_A_5_7061 (9, 2)
# 2JPK_A_10_7145 (14, 2)
# 2JPL_A_1_7159 (11, 2)
# 2JPU_A_5_7170 (9, 2)
# 2JQF_S_1_7180 (2, 2)
# 2JQL_A_4_7181 (9, 2)
# 2JQM_A_19_7190 (13, 2)
# 2JR0_A_13_7203 (9, 2)
# 2JRH_A_3_7221 (9, 2)
# 2JS7_A_3_7243 (18, 2)
# 2JSH_A_5_7261 (15, 2)
# 2JSS_A_3_17334 (86, 2)
# 2JSS_B_8_17335 (5, 2)
# 2JSX_A_3_12588 (20, 2)
# 2JTO_A_1_5326 (1, 2)
# 2JU1_A_16_7316 (15, 2)
# 2JUE_A_4_2759 (4, 2)
# 2JUW_A_7_7331 (18, 2)
# 2JV0_A_4_12651 (7, 2)
# 2JV5_A_4_7355 (9, 2)
# 2JVJ_A_4_14792 (26, 2)
# 2JVV_A_1_18622 (1, 2)
# 2JW8_A_3_7364 (20, 2)
# 2JWA_A_8_7384 (9, 2)
# 2JWD_A_5_7393 (35, 2)
# 2JWS_A_1_8089 (45, 2)
# 2JX2_A_8_7402 (9, 2)
# 2JY5_A_1_7411 (6, 2)
# 2JYI_A_4_7422 (10, 2)
# 2JYU_A_4_7434 (13, 2)
# 2JZI_B_6_14296 (11, 2)
# 2K02_A_1_15187 (1, 2)
# 2K0C_A_1_14133 (1, 2)
# 2K17_A_16_7576 (9, 2)
# 2K1L_B_8_7585 (30, 2)
# 2K1N_A_8_12846 (60, 2)
# 2K1Q_A_1_2138 (6, 2)
# 2K1S_A_18_7615 (19, 2)
# 2LGT_A_6_10367 (11, 2)
# 2LIQ_B_15_10079 (24, 2)
# 2LIW_A_3_10120 (13, 2)
# 2LJ6_A_1_14673 (1, 2)
# 2LJI_A_6_10168 (19, 2)
# 2LJL_A_1_15188 (15, 2)
# 2LJX_A_1_10212 (23, 2)
# 2LJZ_A_1_6320 (14, 2)
# 2LK1_A_1_10220 (13, 2)
# 2LKC_A_12_10242 (9, 2)
# 2LKE_A_4_10264 (35, 2)
# 2LKH_A_9_10251 (13, 2)
# 2LL8_A_14_8933 (15, 2)
# 2LM7_A_8_10394 (11, 2)
# 2LNH_C_5_9040 (20, 2)
# 2LO6_A_6_10474 (9, 2)
# 2LOO_A_13_10499 (14, 2)
# 2LOW_A_12_10513 (20, 2)
# 2LOX_A_10_10533 (19, 2)
# 2LP7_A_2_10563 (32, 2)
# 2LPC_A_15_15101 (44, 2)
# 2LPY_A_5_10572 (14, 2)
# 2LQI_B_1_10585 (14, 2)
# 2LR6_A_4_10599 (9, 2)
# 2LRE_B_4_10608 (22, 2)
# 2LRH_A_11_9805 (16, 2)
# 2LRN_A_4_10630 (13, 2)
# 2LRO_A_3_4290 (5, 2)
# 2LRR_A_15_10644 (23, 2)
# 2LS9_A_4_10666 (10, 2)
# 2LTD_B_10_10734 (70, 2)
# 2LTH_A_8_10689 (13, 2)
# 2LTR_A_2_10720 (9, 2)
# 2LTS_A_2_10723 (5, 2)
# 2LU9_A_7_17453 (16, 2)
# 2LUQ_A_5_10804 (9, 2)
# 2LUZ_A__15403 (10, 2)
# 2LV1_A_10_8838 (40, 2)
# 2LVJ_A_4_10827 (29, 2)
# 2LW8_A_4_13567 (5, 2)
# 2LXA_A_1_15186 (5, 2)
# 2LY2_A_19_10845 (5, 2)
# 2LZJ_A_2_10903 (9, 2)
# 2LZS_A__10912 (18, 2)
# 2M0B_A_2_10921 (9, 2)
# 2M0D_A_3_10930 (12, 2)
# 2M0E_A_15_10937 (5, 2)
# 2M13_A_2_11412 (12, 2)
# 2M1I_A_3_10956 (9, 2)
# 2M3X_D_5_15995 (138, 2)
# 2M41_A_8_15557 (9, 2)
# 2M4F_A_10_10993 (17, 2)
# 2M5E_B_7_11024 (9, 2)
# 2M5H_A_1_15015 (1, 2)
# 2M63_A_1_15241 (6, 2)
# 2M65_A_2_16680 (14, 2)
# 2M6B_A_3_11047 (17, 2)
# 2M7U_A_4_15394 (9, 2)
# 2M8D_A_1_11072 (1, 2)
# 2M8D_B_1_11074 (3, 2)
# 2M8I_A_4_11075 (35, 2)
# 2M8R_A_1_14432 (13, 2)
# 2M94_A_6_11126 (20, 2)
# 2M98_A_4_11147 (10, 2)
# 2MAE_A_5_11156 (11, 2)
# 2MAG_A_2_10680 (13, 2)
# 2MAK_C_13_11167 (18, 2)
# 2MAO_A_1_11188 (6, 2)
# 2MBC_A_1_4295 (3, 2)
# 2MBM_A_1_11192 (21, 2)
# 2MC4_A_1_11206 (3, 2)
# 2MC6_A__17905 (4, 2)
# 2MEY_A_14_11259 (17, 2)
# 2N8Y_A_8_12323 (25, 2)
# 2N9E_A_15_12903 (5, 2)
# 2N9O_A_9_12364 (9, 2)
# 2NA9_A_16_12373 (27, 2)
# 2NB1_A_20_13584 (15, 2)
# 2NCP_A_12_12427 (30, 2)
# 2NCS_A_4_12450 (22, 2)
# 2NCX_A_4_12459 (25, 2)
# 2NDH_A_3_15428 (12, 2)
# 2NS5_A_1_15490 (1, 2)
# 2NXU_A_1_14153 (1, 2)
# 2NZZ_A_10_12500 (15, 2)
# 2O3B_B_1_2360 (5, 2)
# 2OJ2_A_12_12532 (46, 2)
# 2OQP_A_1_14919 (1, 2)
# 2OS6_A_1_12543 (9, 2)
# 2P4L_A_6_12552 (14, 2)
# 2PNI_A_1_12566 (1, 2)
# 2PP4_A_2_12568 (20, 2)
# 2PSP_B__12609 (24, 2)
# 2PVG_A__2905 (2, 2)
# 2PXY_A__14044 (3, 2)
# 2PZV_B__18250 (11, 2)
# 2Q4Y_A_1_12627 (13, 2)
# 2R6C_I__12701 (6, 2)
# 2RCZ_A_1_12716 (12, 2)
# 2REX_C__12726 (10, 2)
# 2RHK_A__8334 (5, 2)
# 2RM0_W_1_12729 (2, 2)
# 2RMZ_A_3_12762 (9, 2)
# 2RNB_A_3_12774 (19, 2)
# 2RND_A_1_12790 (10, 2)
# 2RNK_A_13_7445 (39, 2)
# 2RNM_B_4_12800 (33, 2)
# 2RNR_A_5_12833 (12, 2)
# 2ROK_A_3_12875 (9, 2)
# 2RPJ_A_8_12889 (9, 2)
# 2RPQ_B_1_12898 (21, 2)
# 2RPW_X_1_12971 (1, 2)
# 2RQ6_A_1_17323 (1, 2)
# 2RQH_A_4_13682 (7, 2)
# 2RQW_A_3_13039 (13, 2)
# 2RRH_A_5_13068 (17, 2)
# 2RRU_A_1_3237 (9, 2)
# 2RS9_A_1_13117 (7, 2)
# 2RSF_A_7_13132 (9, 2)
# 2RU3_B_2_13200 (12, 2)
# 2RU4_B_2_13242 (23, 2)
# 2RUK_B_2_13278 (9, 2)
# 2RV5_A_16_13317 (8, 2)
# 2RV6_A_7_13162 (81, 2)
# 2RVA_A_3_16286 (7, 2)
# 2RVM_A_14_13325 (23, 2)
# 2UZI_L__13450 (4, 2)
# 2UZK_C__13453 (3, 2)
# 2V64_B__926 (1, 2)
# 2V83_B__13456 (9, 2)
# 2VN1_A__15921 (21, 2)
# 2VPF_E__14897 (2, 2)
# 2VRD_A_1_15845 (9, 2)
# 2VXF_A_1_6267 (16, 2)
# 2VXP_A__4629 (20, 2)
# 2VY4_A_2_13479 (11, 2)
# 2W1O_A_4_13490 (29, 2)
# 2W7N_B__16359 (8, 2)
# 2WCC_3_1_2306 (1, 2)
# 2WP2_P_1_16460 (1, 2)
# 2WQG_A_21_1631 (14, 2)
# 2WSS_Z__5782 (1, 2)
# 2WTT_A__13638 (77, 2)
# 2WUL_D__13665 (17, 2)
# 2X44_D__18491 (1, 2)
# 2XCJ_A_1_13735 (32, 2)
# 2XDI_A_3_13737 (54, 2)
# 5L7M_A_6_16770 (9, 2)
# 5L87_A_1_16784 (12, 2)
# 5LGF_A_19_16837 (13, 2)
# 5LPU_C_1_16875 (4, 2)
# 5LVF_A_3_8372 (13, 2)
# 5LVQ_B_1_14187 (8, 2)
# 5M1U_A_13_16224 (20, 2)
# 5MFY_A_5_16896 (9, 2)
# 5MR3_A__16547 (3, 2)
# 5MXN_d__16905 (5, 2)
# 5N76_D__18958 (10, 2)
# 5NWM_A_19_2922 (33, 2)
# 5NZ9_A_5_16910 (16, 2)
# 5O2Y_A_4_4000 (6, 2)
# 5OHD_A_3_16926 (9, 2)
# 5OSI_A_1_5202 (5, 2)
# 5TGY_A_1_16941 (12, 2)
# 5TMX_A__255 (18, 2)
# 5TO4_A__15644 (10, 2)
# 5TTT_A_3_16962 (17, 2)
# 5UA8_A_4_16979 (13, 2)
# 5UJG_A_18_16992 (36, 2)
# 5URN_B_4_17028 (13, 2)
# 5UY2_A_19_17041 (19, 2)
# 5VWV_B__6954 (1, 2)
# 5WB2_B_1_17060 (1, 2)
# 5XEE_A_2_402 (21, 2)
# 5XI9_A_8_17131 (30, 2)
# 5XME_A_4_17324 (10, 2)
# 5XOK_B_3_17141 (28, 2)
# 5Y18_A_1_9147 (30, 2)
# 5Y22_A_11_17193 (14, 2)
# 5Y4R_D__5033 (5, 2)
# 5Y8Y_A__18875 (21, 2)
# 5Y95_A_7_17207 (55, 2)
# 5YIP_A__9640 (20, 2)
# 5YPP_A__17235 (23, 2)
# 5YTT_A__17258 (9, 2)
# 5YV7_A__17944 (3, 2)
# 5Z5Q_A_1_17281 (28, 2)
# 5ZE2_N__17442 (16, 2)
# 5ZKL_A__17914 (11, 2)
# 5ZSW_A_3_17298 (14, 2)
# 6A87_D__15899 (5, 2)
# 6AE8_D_1_17343 (2, 2)
# 6AKO_C__17346 (15, 2)
# 6AKP_A__17347 (3, 2)
# 6AKP_B__17350 (1, 2)
# 6B0R_D__17379 (75, 2)
# 6B3U_A_7_16621 (31, 2)
# 6B7G_B_2_12162 (2, 2)
# 6B9W_A_3_17388 (9, 2)
# 6BYH_B__15061 (8, 2)
# 6C6U_N_1_18623 (2, 2)
# 6CHC_A_9_17425 (21, 2)
# 6CO4_A_11_18626 (1, 2)
# 6CW4_A_9_79 (22, 2)
# 6D12_B_1_17447 (5, 2)
# 6D53_C_7_17467 (9, 2)
# 6DMX_A_1_17480 (2, 2)
# 6DNQ_D__17481 (10, 2)
# 6DS2_B__16162 (5, 2)
# 6E27_C__17512 (28, 2)
# 6E5J_A_9_17513 (22, 2)
# 6EJP_A_1_17535 (5, 2)
# 6EU1_F__6017 (4, 2)
# 6EVQ_B_15_17558 (24, 2)
# 6F0Y_A_2_17575 (9, 2)
# 6F4J_D_1_17585 (6, 2)
# 6FEH_A_4_17591 (10, 2)
# 6FFT_B__16456 (1, 2)
# 6FGP_A_4_1172 (28, 2)
# 6G04_A_9_17616 (16, 2)
# 6G4X_A_5_17632 (9, 2)
# 6G5R_A_16_17601 (15, 2)
# 6UBH_A__2618 (16, 2)
# 6UCJ_A_1_18685 (30, 2)
# 6UFR_A__18223 (13, 2)
# 6UX8_A__11842 (11, 2)
# 6UZ4_B_3_18711 (44, 2)
# 6V2D_C__11337 (2, 2)
# 6V2D_K__11336 (1, 2)
# 6VK4_G__19028 (1, 2)
# 6VK5_H__19032 (9, 2)
# 6W2I_A__18840 (12, 2)
# 6W4F_B__11793 (68, 2)
# 6W6O_C__11010 (12, 2)
# 6WA4_A_12_18856 (9, 2)
# 6WAU_A__15212 (30, 2)
# 6WN7_D_1_7962 (32, 2)
# 6WX7_B__18872 (1, 2)
# 6WX8_D__18871 (7, 2)
# 6XCR_A_13_18876 (15, 2)
# 6XFL_A_15_18890 (13, 2)
# 6XWG_A__17589 (1, 2)
# 6Y4P_A__18952 (205, 2)
# 6Y4P_B__18954 (2, 2)
# 6YBG_B__18408 (30, 2)
# 6YEL_A_8_15822 (17, 2)
# 6YI3_A_8_18995 (9, 2)
# 6Z0I_A_15_19033 (9, 2)
# 6ZFM_B__693 (16, 2)
# 6ZN5_f__19060 (1, 2)
# 6ZN5_g__19056 (4, 2)
# 6ZOJ_F__19051 (8, 2)
# 6ZOJ_K__19054 (1, 2)
# 6ZOJ_V__19065 (1, 2)
# 6ZXG_Q__18968 (1, 2)
# 6ZXG_h__18969 (2, 2)
# 6ZZE_A_7_19042 (9, 2)
# 7A58_A_7_19067 (9, 2)
# 7AT7_A_2_19076 (9, 2)
# 7B0Y_G_1_19088 (2, 2)
# 7B0Y_H__19086 (24, 2)
# 7B0Y_h_1_19091 (5, 2)
# 7B3J_A_10_19095 (55, 2)
# 7CHY_I__13464 (1, 2)
# 7D16_A_4_19103 (19, 2)
# 7D44_K__18173 (2, 2)
# 7DC8_C__19122 (2, 2)
# 7JFM_B__5339 (2, 2)
# 7JQB_Q__18970 (1, 2)
# 7JQC_F__19061 (1, 2)
# 7JXG_A_6_19141 (7, 2)
# 7JZV_B__19151 (2, 2)
# 7KLO_A_2_19153 (19, 2)
# 7KRB_A_18_19162 (15, 2)
# 7L54_A_4_19177 (25, 2)

# %%
from numbers import Number
def split_dataset_at_level(df: pd.DataFrame, level_key: str, level_name: str,
                           split_size: dict[str, float] = {"train":0.8, "validation":0.1, "test":0.1}) -> None:
    """Split a dataset into train/validation/test sets, saving the splits into new h5 groups with
    links back to the the main dataset.
    
    Parameters
    ----------
    cath_full_h5 : str
        Path to H5 file on HSDS enpoint
    superfamily : str
        Group prefix, can be empty ('') for h5 file
    sfam_df : pd.DataFrame
        The data frame to split. Each row must a single protein and the df M\must contain 2 columns: 
            (i) "cath_domain", the column of protein domain names, must match groups of the same name in this 'superfamily' group;
            (ii) level_key, custom variable name for the name of the cluster the protein domain belongs to
    level_key : str
        Name of the column that contains cluster names for use in pandas groupby
    level_name : str
        Name of the data split, e.g. "S35"
    split_size : Dict [split_name->split perecent]
        A dictionary containing the total number of splits
    """
    if isinstance(split_size, (list, tuple)):
        if len(split_size)==1:
            assert split_size[0]<1
            other_size = (1-split_size[0])/2
            split_size = dict(zip(["train", "validation", "test"],
                sorted([split_size[0], other_size, other_size])))
        else:
            assert sum(split_size) == 1
            split_size = {f"split{i}":s for i, s in enumerate(split_size)}
    elif isinstance(split_size, Number) and split_size<1:
        other_size = (1-split_size)/2
        split_size = {"train":split_size, "validation":other_size, "test":other_size}
    elif isinstance(split_size, dict) and sum(split_size.values()) == 1:
        #Correct
        pass
    else:
        raise RuntimeError("Invalid split_size. Must be dict {split_name:split_pct}, a list of split sizes (names automatically assinged), or a single number")

    start = 0
    subsets = []

    split_sizes = sorted(split_size.items(), key=lambda x: x[1], reverse=True)

    clusters = df.groupby(level_key)
    sorted_cluster_indices = list(sorted(clusters.indices.keys()))
    split_index_start = 0
    last_size = [None, None]

    for split_num, (split_name, split_pct) in enumerate(split_sizes):
        if split_num < len(split_sizes)-1:
            ideal_set1_size = int(clusters.ngroups*split_pct)

            while True:
                set1_clusters = sorted_cluster_indices[split_index_start:split_index_start+ideal_set1_size]
                set1 = [idx for cluster in set1_clusters for idx in clusters.get_group(cluster).index] #.indices[cluster]]
                size_pct = len(set1)/(len(df))
                print("size", len(set1), len(df), size_pct, ideal_set1_size)
                if size_pct in last_size:
                    break
                if size_pct > split_pct+.01:
                    ideal_set1_size -= 1
                elif size_pct < split_pct-.01:
                    ideal_set1_size += 1
                else:
                    break

                last_size[0] = last_size[1]
                last_size[1] = size_pct

            subset_idx = list(sorted(set1))
            subset = df[df.index.isin(set1)]["pdb"]

            #Reset index for next iteration to skip current domains
            split_index_start += ideal_set1_size
        else:
            set1_clusters = sorted_cluster_indices[split_index_start:]
            set1 = [idx for cluster in set1_clusters for idx in clusters.get_group(cluster).index] #.indices[cluster]]
            size_pct = len(set1)/(len(df))
            subset = df[df.index.isin(set1)]["pdb"]

        yield subset

# %%
train, valid, test = split_dataset_at_level(trainValClusters, "group", "dummy")
# Out:
# size 15394 19202 0.8016873242370587 1014
# size 1713 19202 0.0892094573481929 126
# size 1722 19202 0.08967815852515364 127
# size 1735 19202 0.09035517133631914 128

# %%
train
# Out:
# 0         2LC6_A_2_9771
# 1         1RY4_A_8_9772
# 2         2LC6_A_7_9773
# 3        1RY4_A_10_9774
# 4         2LC6_A_3_9775
#               ...
# 19197     2LB6_A_2_9766
# 19198     2LB6_A_6_9767
# 19199     2LB6_A_5_9768
# 19200    2LB6_A_10_9769
# 19201     2LB6_A_4_9770
# Name: pdb, Length: 15394, dtype: object

# %%
train.to_csv("train.csv")

# %%
valid.to_csv("valid.csv")

# %%
test.to_csv("test.csv")

# %%
set(all_data_df.causes.str.lower().str.split(";", expand=True).values.flatten())
# Out:
# {None,
#  'disorder',
#  'ligand',
#  'ligand biolip',
#  'mutation',
#  'oligomeric state',
#  'oligomeric state author',
#  'ph',
#  'post-translational mod',
#  'temperature',
#  'without causes of dc'}

# %%
train = train.str.split("_", expand=True)[[0,1,2]].rename(columns={0:"pdb", 1:"chain", 2:"model"})

# %%
train_df = pd.merge(train, all_data_df.drop(columns=emb_cols), how="left", on=["pdb", "chain", "model"]).drop_duplicates(subset=["pdb", "chain", "model"])

# %%
a.drop_duplicates(subset=["pdb", "chain", "model"])
# Out:
#         pdb chain model  pdb_index   cluster_id  pdb_cluster_id  \
# 0      2LC6     A     2    14024.0  2LC6_A_seqs   2LC6_A_seqs_0
# 1      1RY4     A     8    14025.0  2LC6_A_seqs   2LC6_A_seqs_1
# 2      2LC6     A     7    14026.0  2LC6_A_seqs   2LC6_A_seqs_2
# 3      1RY4     A    10    14027.0  2LC6_A_seqs   2LC6_A_seqs_3
# 4      2LC6     A     3    14028.0  2LC6_A_seqs   2LC6_A_seqs_4
# ...     ...   ...   ...        ...          ...             ...
# 15753  2LB6     A     2    12943.0  2LB6_A_seqs  2LB6_A_seqs_12
# 15754  2LB6     A     6    12944.0  2LB6_A_seqs  2LB6_A_seqs_13
# 15755  2LB6     A     5    12945.0  2LB6_A_seqs  2LB6_A_seqs_14
# 15756  2LB6     A    10    12946.0  2LB6_A_seqs  2LB6_A_seqs_15
# 15757  2LB6     A     4    12947.0  2LB6_A_seqs  2LB6_A_seqs_16
#
#                                                file_name                causes
# 0       codnas_groups_pdb/2LC6_A_seqs/2LC6-2-A_fixed.pdb  TEMPERATURE;MUTATION
# 1       codnas_groups_pdb/2LC6_A_seqs/1RY4-8-A_fixed.pdb  TEMPERATURE;MUTATION
# 2       codnas_groups_pdb/2LC6_A_seqs/2LC6-7-A_fixed.pdb              MUTATION
# 3      codnas_groups_pdb/2LC6_A_seqs/1RY4-10-A_fixed.pdb  TEMPERATURE;MUTATION
# 4       codnas_groups_pdb/2LC6_A_seqs/2LC6-3-A_fixed.pdb  TEMPERATURE;MUTATION
# ...                                                  ...                   ...
# 15753   codnas_groups_pdb/2LB6_A_seqs/2LB6-2-A_fixed.pdb  WITHOUT CAUSES OF DC
# 15754   codnas_groups_pdb/2LB6_A_seqs/2LB6-6-A_fixed.pdb  WITHOUT CAUSES OF DC
# 15755   codnas_groups_pdb/2LB6_A_seqs/2LB6-5-A_fixed.pdb  WITHOUT CAUSES OF DC
# 15756  codnas_groups_pdb/2LB6_A_seqs/2LB6-10-A_fixed.pdb  WITHOUT CAUSES OF DC
# 15757   codnas_groups_pdb/2LB6_A_seqs/2LB6-4-A_fixed.pdb  WITHOUT CAUSES OF DC
#
# [15205 rows x 8 columns]

# %%
train_df.to_csv("train_df.csv")

# %%
valid_df = pd.merge(
    valid.str.split("_", expand=True)[[0,1,2]].rename(columns={0:"pdb", 1:"chain", 2:"model"}), 
    all_data_df.drop(columns=emb_cols), how="left", on=["pdb", "chain", "model"]).drop_duplicates(subset=["pdb", "chain", "model"])

# %%
valid_df.to_csv("valid_df.csv")

# %%
test_df = pd.merge(
    test.str.split("_", expand=True)[[0,1,2]].rename(columns={0:"pdb", 1:"chain", 2:"model"}), 
    all_data_df.drop(columns=emb_cols), how="left", on=["pdb", "chain", "model"]).drop_duplicates(subset=["pdb", "chain", "model"])

# %%
test_df.to_csv("test_df.csv")

# %%
embeddings_df =
